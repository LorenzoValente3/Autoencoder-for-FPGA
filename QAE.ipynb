# %%
import tensorflow as tf
from tensorflow.python.keras import Input
from tensorflow.python.keras.models import Model, Sequential
from tensorflow.python.keras.engine.keras_tensor import KerasTensor
from tensorflow.python.keras.engine.functional import Functional
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Activation
from tensorflow.python.keras.regularizers import l2
import os

from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning, prune_low_magnitude

from callbacks import all_callbacks
from tensorflow.keras.regularizers import l1

# %%
from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu

# %% [markdown]
# ### Import the MNIST data class and call it.

# %% [markdown]
# Original dataset and modified dataset with modifiable resolution is shown below.

# %%
import MNIST_dataset as mnist
size_final = 28

data = mnist.MNISTData(size_initial=28, size_final=size_final, color_depth=8)
train= data.x_train
ax = plt.subplot(1, 1 , 1)

plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %%
import MNIST_dataset as mnist

#Choose the final size of your image dataset
size_final = 8

data_zoom = mnist.MNISTData(size_initial=20, size_final=size_final, color_depth=5, flat=True)
train= data_zoom.x_train
ax = plt.subplot(1, 1 , 1)

plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
class QAutoencoder:
    """Autoencoder Class"""

    def __init__(self, data: mnist.MNISTData, num_classes=10, pruned = False):
        self.x_train = data.x_train
        self.x_test = data.x_test
        self.y_train = data.y_train
        self.y_test = data.y_test

        self.num_classes = num_classes
        self.pruned = pruned
        self.input_shape = (self.x_train.shape[-1],)
        self.input = Input(shape=self.input_shape, name='encoder_input')
        self.latent_dim = 2

        self.encoder = None
        self.encoder_model = None
        self.decoder = None
        self.decoder_model = None
        self.latent_classifier = None
        self.autoencoder = None

        self.history = None

        self.pruning_params = {"pruning_schedule" : pruning_schedule.ConstantSparsity(0.8, begin_step=2000, end_step=10000, frequency=100)}
    
    def build_encoder(self):
        """Build your encoder architecture and store the output in self.encoder. 
        The final encoding dimension is 2."""

        self.encoder = QDense(32,  name='fc1',
                        kernel_quantizer=quantized_bits(4,0, alpha=1),
                        bias_quantizer=quantized_bits(4,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.input)
        self.encoder = QActivation(activation=quantized_relu(4), name='relu1')(self.encoder)

        if self.pruned:
            self.encoder = prune_low_magnitude(QDense(16,  name='fc2_prun',
                        kernel_quantizer=quantized_bits(4, 0, alpha=1),
                        bias_quantizer=quantized_bits(4, 0, alpha=1),
                        kernel_initializer='lecun_uniform'), **self.pruning_params)(self.encoder) 
            self.encoder = QActivation(activation=quantized_relu(4), name='relu2')(self.encoder)
        
        if not self.pruned:
            self.encoder = QDense(16,  name='fc2',
                        kernel_quantizer=quantized_bits(4,0,alpha=1),
                        bias_quantizer=quantized_bits(4,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.encoder)
            self.encoder = QActivation(activation=quantized_relu(4), name='relu2')(self.encoder)
        
        self.encoder = Dense(self.latent_dim,  activation='relu', name = 'encoder_output')(self.encoder)

        #building a model for the encoder in order to be able to predict and plot the latent dimension
        self.encoder_model = Model(self.input, self.encoder, name='encoder')

    def build_decoder(self):
        """Build the decoder architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the decoder!")
           
        if self.pruned:
            self.decoder = prune_low_magnitude(QDense(16,  name='fc3',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0,alpha=1),
                        kernel_initializer='lecun_uniform'), **self.pruning_params)(self.encoder)
            self.decoder= QActivation(activation=quantized_relu(5,0), name='relu3')(self.decoder)

        if not self.pruned:
            self.decoder = QDense(16,  name='fc3',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.encoder)
            self.decoder=QActivation(activation=quantized_relu(5), name='relu3')(self.decoder)

        self.decoder = QDense(32,  name='fc4',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.decoder)
        self.decoder = QActivation(activation=quantized_relu(5), name='relu4')(self.decoder) 

        self.decoder = QDense(self.input_shape[0],name='decoder_output',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.decoder)
        self.decoder = Activation(activation='sigmoid', name='sigmoid')(self.decoder)
        
    def build_classifier(self):
        """ Building the classifier architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the classifier!")
        
        if self.pruned:
            self.latent_classifier = prune_low_magnitude(QDense(16,  name='fc4_prunedclass',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0,alpha=1),
                        kernel_initializer='lecun_uniform', 
                        kernel_regularizer=l1(0.0001)), **self.pruning_params)(self.encoder)
            self.latent_classifier = QActivation(activation=quantized_relu(5,0), name='prunclass_relu4')(self.latent_classifier)
        
        if not self.pruned:
            self.latent_classifier = QDense(16,  name='fc4_class',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0, alpha=1),
                        kernel_initializer='lecun_uniform',
                        kernel_regularizer=l1(0.0001))(self.encoder)
            self.latent_classifier=QActivation(activation=quantized_relu(5), name='class_relu4')(self.latent_classifier)

        self.latent_classifier = QDense(32,  name='fc5_class',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0, alpha=1),
                        kernel_initializer='lecun_uniform', 
                        kernel_regularizer=l1(0.0001))(self.latent_classifier)
        self.latent_classifier = QActivation(activation=quantized_relu(5), name='class_relu5')(self.latent_classifier)
        
        self.latent_classifier = QDense(self.num_classes,  name='classifier_out',
                        kernel_quantizer=quantized_bits(16,6,alpha=1),
                        bias_quantizer=quantized_bits(16,6, alpha=1),
                        kernel_initializer='lecun_uniform', 
                        kernel_regularizer=l1(0.0001))(self.latent_classifier)
        self.latent_classifier = Activation(activation='softmax', name = 'classifier_output')(self.latent_classifier)
        
    def build_autoencoder(self, use_latent_classifier=False):
        """ Build the whole autoencoder Model from self.encoder and self.decoder."""
        self.dir()
        
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the autoencoder!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")
        
        if use_latent_classifier:
            if self.latent_classifier is None:
                raise RuntimeError("If you want to use the option with the latent classifier, you have to build it "
                                   "beforehand!")
            self.autoencoder = Model(self.input, outputs=[self.decoder, self.latent_classifier])
            self.autoencoder.compile(loss=['mse', 'categorical_crossentropy'], loss_weights=[1, 0.1], optimizer='adam',
                                     metrics="accuracy")
            if not self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_model_w_classifier.h5')
            if self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_pruned_model_w_classifier.h5')
    
        else:
            self.autoencoder = Model(self.input, outputs=self.decoder, name = 'autoencoder')
            self.autoencoder.compile(loss='mse', optimizer='adam') 
            if not self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_model_wo_classifier.h5')
            if self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_pruned_model_wo_classifier.h5')
        self.autoencoder.summary()
        
    def fit_data(self, batch_size=256, epochs=30, use_latent_classifier=False):
        """Write the fit function for the autoencoder. 
        Storing the fit history in self.history to be able to plot the fitting scores."""
        
        callbacks = all_callbacks(stop_patience = 1000,        
                              lr_factor = 0.5,
                              lr_patience = 10,
                              lr_epsilon = 0.000001,
                              lr_cooldown = 2,
                              lr_minimum = 0.0000001,
                              outputDir = 'model/QAE_model/model_2')
        callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep()) 
        
        if use_latent_classifier:
            self.history = self.autoencoder.fit(self.x_train, [self.x_train, self.y_train],
                                                validation_data=(self.x_test, [self.x_test, self.y_test]),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True, callbacks=callbacks.callbacks)
            self.autoencoder = strip_pruning(self.autoencoder)
            if not self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_best_model_classifier.h5')
            if self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_pruned_best_model_classifier.h5')
        else:                         
            self.history = self.autoencoder.fit(self.x_train, self.x_train,
                                                validation_data=(self.x_test, self.x_test),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True, callbacks=callbacks.callbacks)  
            self.autoencoder = strip_pruning(self.autoencoder)
            if not self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_best_model.h5')
            if self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_pruned_best_model.h5')

        self.history = self.history.history

    def dir(self):
        """Creation of the folders path to store the results."""
        dir = os.path.join("images")
        if not os.path.exists(dir):
            os.mkdir(dir)
        dir2 = os.path.join("./images/QAE")
        if not os.path.exists(dir2):
            os.mkdir(dir2)
        dir3 = os.path.join("model")
        if not os.path.exists(dir3):
            os.mkdir(dir3)
        dir4 = os.path.join("./model/QAE_model")
        if not os.path.exists(dir4):
            os.mkdir(dir4)
        
    
    def plot_score(self, use_latent_classifier = False, model_name=None):
        """Plots the scores achieved during the fitting."""
        if use_latent_classifier is False:
            plt.plot(self.history['loss'])
            plt.plot(self.history['val_loss'])
            plt.ylabel('Model Accuracy')
        else:
            plt.plot(self.history['classifier_output_accuracy'])
            plt.plot(self.history['val_classifier_output_accuracy'])
            plt.ylabel('Classifier Accuracy')
        
        plt.xlabel('Epoch')        
        plt.legend(['Train', 'Test'], loc='best')
        plt.title('Accuracy of {model_name}'.format(model_name=model_name))
        
        plt.savefig('./images/QAE/Accuracy of {model_name}.png'.format(model_name=model_name))
        
        plt.show()

    def plot_latent_dimension(self, model_name = None):
        """Plots the latent dimension of the autoencoder."""
        prediction = self.encoder_model.predict(self.x_test)
        fig = plt.figure(figsize=(10, 10))
        fig.patch.set_facecolor("white")
        plt.scatter(prediction[:, 0], prediction[:, 1], c=np.argmax(self.y_test, axis=1), cmap="Set3")
        plt.colorbar()
        plt.title('Latent space {model_name}'.format(model_name=model_name))


        plt.savefig('./images/QAE/Latent dimension of {model_name}.png'.format(model_name=model_name))

        plt.show()

    def plot_reco(self, use_latent_classifier = False, model_name = None):
        """Plotting reconstructed images"""
        
        n = 6
        plt.figure(figsize=(10, 3))
        reco_imgs = self.autoencoder.predict(self.x_test)
        img_size = int(np.sqrt(self.input_shape[0]))

        
        if use_latent_classifier :
            raise RuntimeError("You are considering the autoencoder with classifier!")
        else:
        
            for i in range(n):
                # Display original MNIST
                ax = plt.subplot(2, n, i + 1)
                plt.imshow(self.x_test[i].reshape(img_size,img_size), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)

                # Display reconstructed MNIST            
                ax = plt.subplot(2, n, i + n + 1)
                plt.imshow(reco_imgs[i].reshape(img_size,img_size), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)
            
            plt.savefig('./images/QAE/reconstructed images{model_name}.png'.format(model_name=model_name))
            plt.show()
            
    def plot_latent(self):
        n = 6
        plt.figure(figsize=(10, 3))
        reco_imgs = self.encoder_model.predict(self.x_test)
        img_size = int(np.sqrt(self.input_shape[0]))

        ax = plt.subplot(1, 1, 1)
        plt.imshow(reco_imgs[1].reshape(2,1), cmap='gray_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        plt.show()

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = QAutoencoder(data_zoom, pruned=False)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("QAutoencoder without classifier")
network.plot_reco(model_name=" complete")
network.plot_score(use_latent_classifier=False, model_name="Autoencoder without classifier")
network.plot_latent()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 64)]              0
# _________________________________________________________________
# fc1 (QDense)                 (None, 32)                2080
# _________________________________________________________________
# relu1 (QActivation)          (None, 32)                0
# _________________________________________________________________
# fc2 (QDense)                 (None, 16)                528
# _________________________________________________________________
# relu2 (QActivation)          (None, 16)                0
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 34
# _________________________________________________________________
# fc3 (QDense)                 (None, 16)                48
# _________________________________________________________________
# relu3 (QActivation)          (None, 16)                0
# _________________________________________________________________
# fc4 (QDense)                 (None, 32)                544
# _________________________________________________________________
# relu4 (QActivation)          (None, 32)                0
# _________________________________________________________________
# decoder_output (QDense)      (None, 64)                2112
# _________________________________________________________________
# sigmoid (Activation)         (None, 64)                0
# =================================================================
# Total params: 5,346
# Trainable params: 5,346
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/40
#   2/235 [..............................] - ETA: 2:23 - loss: 0.2078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 1.2350s). Check your callbacks.
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1258
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00001: val_loss improved from inf to 0.09967, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 0.09967, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1250 - val_loss: 0.0997
# Epoch 2/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0960
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00002: val_loss improved from 0.09967 to 0.08929, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 0.09967 to 0.08929, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0958 - val_loss: 0.0893
# Epoch 3/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0850
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00003: val_loss improved from 0.08929 to 0.08172, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 0.08929 to 0.08172, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0850 - val_loss: 0.0817
# Epoch 4/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0805
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00004: val_loss improved from 0.08172 to 0.07900, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.08172 to 0.07900, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0805 - val_loss: 0.0790
# Epoch 5/40
# 219/235 [==========================>...] - ETA: 0s - loss: 0.0780
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00005: val_loss improved from 0.07900 to 0.07673, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00005: val_loss improved from 0.07900 to 0.07673, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0780 - val_loss: 0.0767
# Epoch 6/40
# 218/235 [==========================>...] - ETA: 0s - loss: 0.0763
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00006: val_loss improved from 0.07673 to 0.07531, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00006: val_loss improved from 0.07673 to 0.07531, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0762 - val_loss: 0.0753
# Epoch 7/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0750
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00007: val_loss improved from 0.07531 to 0.07477, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00007: val_loss improved from 0.07531 to 0.07477, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0750 - val_loss: 0.0748
# Epoch 8/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.0742
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00008: val_loss improved from 0.07477 to 0.07362, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00008: val_loss improved from 0.07477 to 0.07362, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0742 - val_loss: 0.0736
# Epoch 9/40
# 210/235 [=========================>....] - ETA: 0s - loss: 0.0733
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00009: val_loss improved from 0.07362 to 0.07276, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00009: val_loss improved from 0.07362 to 0.07276, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0733 - val_loss: 0.0728
# Epoch 10/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.0724
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00010: val_loss improved from 0.07276 to 0.07187, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00010: val_loss improved from 0.07276 to 0.07187, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0724 - val_loss: 0.0719
# Epoch 11/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0715
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00011: val_loss improved from 0.07187 to 0.07106, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00011: val_loss improved from 0.07187 to 0.07106, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0715 - val_loss: 0.0711
# Epoch 12/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0706
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00012: val_loss improved from 0.07106 to 0.07021, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00012: val_loss improved from 0.07106 to 0.07021, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0706 - val_loss: 0.0702
# Epoch 13/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.0701
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00013: val_loss improved from 0.07021 to 0.06989, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00013: val_loss improved from 0.07021 to 0.06989, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0701 - val_loss: 0.0699
# Epoch 14/40
# 215/235 [==========================>...] - ETA: 0s - loss: 0.0696
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00014: val_loss improved from 0.06989 to 0.06973, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00014: val_loss improved from 0.06989 to 0.06973, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0696 - val_loss: 0.0697
# Epoch 15/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0690
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00015: val_loss improved from 0.06973 to 0.06861, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00015: val_loss improved from 0.06973 to 0.06861, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0690 - val_loss: 0.0686
# Epoch 16/40
# 214/235 [==========================>...] - ETA: 0s - loss: 0.0687
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00016: val_loss improved from 0.06861 to 0.06822, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00016: val_loss improved from 0.06861 to 0.06822, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0686 - val_loss: 0.0682
# Epoch 17/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0682
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00017: val_loss did not improve from 0.06822
#
# Epoch 00017: val_loss did not improve from 0.06822
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0682 - val_loss: 0.0683
# Epoch 18/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0678
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00018: val_loss improved from 0.06822 to 0.06738, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 0.06822 to 0.06738, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0678 - val_loss: 0.0674
# Epoch 19/40
# 217/235 [==========================>...] - ETA: 0s - loss: 0.0674
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00019: val_loss improved from 0.06738 to 0.06736, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00019: val_loss improved from 0.06738 to 0.06736, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0674 - val_loss: 0.0674
# Epoch 20/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0671
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00020: val_loss improved from 0.06736 to 0.06703, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00020: val_loss improved from 0.06736 to 0.06703, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0671 - val_loss: 0.0670
# Epoch 21/40
# 207/235 [=========================>....] - ETA: 0s - loss: 0.0668
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00021: val_loss did not improve from 0.06703
#
# Epoch 00021: val_loss did not improve from 0.06703
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0668 - val_loss: 0.0670
# Epoch 22/40
# 217/235 [==========================>...] - ETA: 0s - loss: 0.0667
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00022: val_loss improved from 0.06703 to 0.06644, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00022: val_loss improved from 0.06703 to 0.06644, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0667 - val_loss: 0.0664
# Epoch 23/40
# 211/235 [=========================>....] - ETA: 0s - loss: 0.0665
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00023: val_loss improved from 0.06644 to 0.06610, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 0.06644 to 0.06610, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0665 - val_loss: 0.0661
# Epoch 24/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0663
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00024: val_loss did not improve from 0.06610
#
# Epoch 00024: val_loss did not improve from 0.06610
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0663 - val_loss: 0.0663
# Epoch 25/40
# 219/235 [==========================>...] - ETA: 0s - loss: 0.0661
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00025: val_loss did not improve from 0.06610
#
# Epoch 00025: val_loss did not improve from 0.06610
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0660 - val_loss: 0.0661
# Epoch 26/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0658
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00026: val_loss improved from 0.06610 to 0.06562, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00026: val_loss improved from 0.06610 to 0.06562, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0658 - val_loss: 0.0656
# Epoch 27/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0656
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00027: val_loss did not improve from 0.06562
#
# Epoch 00027: val_loss did not improve from 0.06562
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0656 - val_loss: 0.0666
# Epoch 28/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.0654
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00028: val_loss improved from 0.06562 to 0.06544, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.06562 to 0.06544, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0654 - val_loss: 0.0654
# Epoch 29/40
# 218/235 [==========================>...] - ETA: 0s - loss: 0.0652
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00029: val_loss improved from 0.06544 to 0.06503, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00029: val_loss improved from 0.06544 to 0.06503, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0651 - val_loss: 0.0650
# Epoch 30/40
# 220/235 [===========================>..] - ETA: 0s - loss: 0.0651
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00030: val_loss did not improve from 0.06503
#
# Epoch 00030: val_loss did not improve from 0.06503
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0650 - val_loss: 0.0654
# Epoch 31/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0650
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00031: val_loss did not improve from 0.06503
#
# Epoch 00031: val_loss did not improve from 0.06503
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0650 - val_loss: 0.0657
# Epoch 32/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0648
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00032: val_loss did not improve from 0.06503
#
# Epoch 00032: val_loss did not improve from 0.06503
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0649 - val_loss: 0.0653
# Epoch 33/40
# 218/235 [==========================>...] - ETA: 0s - loss: 0.0648
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00033: val_loss improved from 0.06503 to 0.06463, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00033: val_loss improved from 0.06503 to 0.06463, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0648 - val_loss: 0.0646
# Epoch 34/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0647
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00034: val_loss did not improve from 0.06463
#
# Epoch 00034: val_loss did not improve from 0.06463
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0647 - val_loss: 0.0647
# Epoch 35/40
# 215/235 [==========================>...] - ETA: 0s - loss: 0.0646
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00035: val_loss did not improve from 0.06463
#
# Epoch 00035: val_loss did not improve from 0.06463
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0646 - val_loss: 0.0649
# Epoch 36/40
# 220/235 [===========================>..] - ETA: 0s - loss: 0.0644
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00036: val_loss improved from 0.06463 to 0.06461, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00036: val_loss improved from 0.06463 to 0.06461, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0645 - val_loss: 0.0646
# Epoch 37/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0645
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00037: val_loss did not improve from 0.06461
#
# Epoch 00037: val_loss did not improve from 0.06461
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0645 - val_loss: 0.0648
# Epoch 38/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0643
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00038: val_loss improved from 0.06461 to 0.06421, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00038: val_loss improved from 0.06461 to 0.06421, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0643 - val_loss: 0.0642
# Epoch 39/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0640
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00039: val_loss improved from 0.06421 to 0.06403, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00039: val_loss improved from 0.06421 to 0.06403, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0640 - val_loss: 0.0640
# Epoch 40/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0639
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00040: val_loss did not improve from 0.06403
#
# Epoch 00040: val_loss did not improve from 0.06403
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0639 - val_loss: 0.0641

# %%
network = QAutoencoder(data_zoom, pruned=True)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("Compressed QAE without classifier")
network.plot_reco(model_name=" compressed")
network.plot_score(use_latent_classifier=False,model_name="Compressed QAE without classifier")
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 64)]              0
# _________________________________________________________________
# fc1 (QDense)                 (None, 32)                2080
# _________________________________________________________________
# relu1 (QActivation)          (None, 32)                0
# _________________________________________________________________
# prune_low_magnitude_fc2_prun (None, 16)                1042
# _________________________________________________________________
# relu2 (QActivation)          (None, 16)                0
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 34
# _________________________________________________________________
# prune_low_magnitude_fc3 (Pru (None, 16)                82
# _________________________________________________________________
# relu3 (QActivation)          (None, 16)                0
# _________________________________________________________________
# fc4 (QDense)                 (None, 32)                544
# _________________________________________________________________
# relu4 (QActivation)          (None, 32)                0
# _________________________________________________________________
# decoder_output (QDense)      (None, 64)                2112
# _________________________________________________________________
# sigmoid (Activation)         (None, 64)                0
# =================================================================
# Total params: 5,894
# Trainable params: 5,346
# Non-trainable params: 548
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/40
#   2/235 [..............................] - ETA: 2:47 - loss: 0.2094WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 1.4400s). Check your callbacks.
# 235/235 [==============================] - ETA: 0s - loss: 0.1186
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00001: val_loss improved from inf to 0.09428, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 0.09428, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1186 - val_loss: 0.0943
# Epoch 2/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0910
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00002: val_loss improved from 0.09428 to 0.08919, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 0.09428 to 0.08919, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0910 - val_loss: 0.0892
# Epoch 3/40
# 211/235 [=========================>....] - ETA: 0s - loss: 0.0874
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00003: val_loss improved from 0.08919 to 0.08464, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 0.08919 to 0.08464, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0872 - val_loss: 0.0846
# Epoch 4/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0822
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00004: val_loss improved from 0.08464 to 0.07893, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.08464 to 0.07893, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0821 - val_loss: 0.0789
# Epoch 5/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0774
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00005: val_loss improved from 0.07893 to 0.07556, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00005: val_loss improved from 0.07893 to 0.07556, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0773 - val_loss: 0.0756
# Epoch 6/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.0751
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00006: val_loss improved from 0.07556 to 0.07399, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00006: val_loss improved from 0.07556 to 0.07399, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0751 - val_loss: 0.0740
# Epoch 7/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.0737
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00007: val_loss improved from 0.07399 to 0.07343, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00007: val_loss improved from 0.07399 to 0.07343, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0737 - val_loss: 0.0734
# Epoch 8/40
# 209/235 [=========================>....] - ETA: 0s - loss: 0.0728
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00008: val_loss improved from 0.07343 to 0.07219, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00008: val_loss improved from 0.07343 to 0.07219, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0728 - val_loss: 0.0722
# Epoch 9/40
# 212/235 [==========================>...] - ETA: 0s - loss: 0.0790
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00009: val_loss did not improve from 0.07219
#
# Epoch 00009: val_loss did not improve from 0.07219
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0792 - val_loss: 0.0807
# Epoch 10/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0794
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00010: val_loss did not improve from 0.07219
#
# Epoch 00010: val_loss did not improve from 0.07219
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0793 - val_loss: 0.0780
# Epoch 11/40
# 210/235 [=========================>....] - ETA: 0s - loss: 0.0773
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00011: val_loss did not improve from 0.07219
#
# Epoch 00011: val_loss did not improve from 0.07219
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0773 - val_loss: 0.0764
# Epoch 12/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0760
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00012: val_loss did not improve from 0.07219
#
# Epoch 00012: val_loss did not improve from 0.07219
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0760 - val_loss: 0.0753
# Epoch 13/40
# 205/235 [=========================>....] - ETA: 0s - loss: 0.0748
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00013: val_loss did not improve from 0.07219
#
# Epoch 00013: val_loss did not improve from 0.07219
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0747 - val_loss: 0.0740
# Epoch 14/40
# 210/235 [=========================>....] - ETA: 0s - loss: 0.0738
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00014: val_loss did not improve from 0.07219
#
# Epoch 00014: val_loss did not improve from 0.07219
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0738 - val_loss: 0.0731
# Epoch 15/40
# 214/235 [==========================>...] - ETA: 0s - loss: 0.0732
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00015: val_loss did not improve from 0.07219
#
# Epoch 00015: val_loss did not improve from 0.07219
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0731 - val_loss: 0.0729
# Epoch 16/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0725
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00016: val_loss did not improve from 0.07219
#
# Epoch 00016: val_loss did not improve from 0.07219
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0725 - val_loss: 0.0723
# Epoch 17/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.0721- ETA: 0s - loss:
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00017: val_loss improved from 0.07219 to 0.07165, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00017: val_loss improved from 0.07219 to 0.07165, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0721 - val_loss: 0.0717
# Epoch 18/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0720
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00018: val_loss improved from 0.07165 to 0.07160, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 0.07165 to 0.07160, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0720 - val_loss: 0.0716
# Epoch 19/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0719
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00019: val_loss improved from 0.07160 to 0.07099, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00019: val_loss improved from 0.07160 to 0.07099, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0719 - val_loss: 0.0710
# Epoch 20/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0713- ET
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00020: val_loss did not improve from 0.07099
#
# Epoch 00020: val_loss did not improve from 0.07099
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0713 - val_loss: 0.0716
# Epoch 21/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0712
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00021: val_loss improved from 0.07099 to 0.07061, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00021: val_loss improved from 0.07099 to 0.07061, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0711 - val_loss: 0.0706
# Epoch 22/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.0709
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00022: val_loss did not improve from 0.07061
#
# Epoch 00022: val_loss did not improve from 0.07061
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0709 - val_loss: 0.0707
# Epoch 23/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0705
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00023: val_loss improved from 0.07061 to 0.07031, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 0.07061 to 0.07031, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0705 - val_loss: 0.0703
# Epoch 24/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0704
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00024: val_loss improved from 0.07031 to 0.07026, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00024: val_loss improved from 0.07031 to 0.07026, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0704 - val_loss: 0.0703
# Epoch 25/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0702
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00025: val_loss did not improve from 0.07026
#
# Epoch 00025: val_loss did not improve from 0.07026
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0702 - val_loss: 0.0703
# Epoch 26/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0700
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00026: val_loss improved from 0.07026 to 0.06986, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00026: val_loss improved from 0.07026 to 0.06986, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0700 - val_loss: 0.0699
# Epoch 27/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0700
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00027: val_loss did not improve from 0.06986
#
# Epoch 00027: val_loss did not improve from 0.06986
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0700 - val_loss: 0.0699
# Epoch 28/40
# 209/235 [=========================>....] - ETA: 0s - loss: 0.0699
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00028: val_loss improved from 0.06986 to 0.06951, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.06986 to 0.06951, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0699 - val_loss: 0.0695
# Epoch 29/40
# 210/235 [=========================>....] - ETA: 0s - loss: 0.0696
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00029: val_loss did not improve from 0.06951
#
# Epoch 00029: val_loss did not improve from 0.06951
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0695 - val_loss: 0.0703
# Epoch 30/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0694
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00030: val_loss improved from 0.06951 to 0.06917, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00030: val_loss improved from 0.06951 to 0.06917, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0693 - val_loss: 0.0692
# Epoch 31/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0692
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00031: val_loss did not improve from 0.06917
#
# Epoch 00031: val_loss did not improve from 0.06917
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0692 - val_loss: 0.0692
# Epoch 32/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0691
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00032: val_loss improved from 0.06917 to 0.06883, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00032: val_loss improved from 0.06917 to 0.06883, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0691 - val_loss: 0.0688
# Epoch 33/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0690
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00033: val_loss did not improve from 0.06883
#
# Epoch 00033: val_loss did not improve from 0.06883
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0690 - val_loss: 0.0690
# Epoch 34/40
# 213/235 [==========================>...] - ETA: 0s - loss: 0.0689
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00034: val_loss improved from 0.06883 to 0.06871, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00034: val_loss improved from 0.06883 to 0.06871, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0689 - val_loss: 0.0687
# Epoch 35/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0689
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00035: val_loss did not improve from 0.06871
#
# Epoch 00035: val_loss did not improve from 0.06871
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0689 - val_loss: 0.0689
# Epoch 36/40
# 212/235 [==========================>...] - ETA: 0s - loss: 0.0688
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00036: val_loss improved from 0.06871 to 0.06844, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00036: val_loss improved from 0.06871 to 0.06844, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0687 - val_loss: 0.0684
# Epoch 37/40
# 212/235 [==========================>...] - ETA: 0s - loss: 0.0687
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00037: val_loss did not improve from 0.06844
#
# Epoch 00037: val_loss did not improve from 0.06844
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0686 - val_loss: 0.0685
# Epoch 38/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0685
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00038: val_loss did not improve from 0.06844
#
# Epoch 00038: val_loss did not improve from 0.06844
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0685 - val_loss: 0.0686
# Epoch 39/40
# 217/235 [==========================>...] - ETA: 0s - loss: 0.0684
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00039: val_loss did not improve from 0.06844
#
# Epoch 00039: val_loss did not improve from 0.06844
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0684 - val_loss: 0.0685
# Epoch 40/40
# 208/235 [=========================>....] - ETA: 0s - loss: 0.0684
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00040: val_loss did not improve from 0.06844
#
# Epoch 00040: val_loss did not improve from 0.06844
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0683 - val_loss: 0.0687

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=False)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data( batch_size=256,epochs=40, use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("QAutoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="QAutoencoder with classifier")
# Out:
# Model: "functional_53"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 64)]         0
# __________________________________________________________________________________________________
# fc1 (QDense)                    (None, 32)           2080        encoder_input[0][0]
# __________________________________________________________________________________________________
# relu1 (QActivation)             (None, 32)           0           fc1[0][0]
# __________________________________________________________________________________________________
# fc2 (QDense)                    (None, 16)           528         relu1[0][0]
# __________________________________________________________________________________________________
# relu2 (QActivation)             (None, 16)           0           fc2[0][0]
# __________________________________________________________________________________________________
# encoder_output (Dense)          (None, 2)            34          relu2[0][0]
# __________________________________________________________________________________________________
# fc3 (QDense)                    (None, 16)           48          encoder_output[0][0]
# __________________________________________________________________________________________________
# fc4_class (QDense)              (None, 16)           48          encoder_output[0][0]
# __________________________________________________________________________________________________
# relu3 (QActivation)             (None, 16)           0           fc3[0][0]
# __________________________________________________________________________________________________
# class_relu4 (QActivation)       (None, 16)           0           fc4_class[0][0]
# __________________________________________________________________________________________________
# fc4 (QDense)                    (None, 32)           544         relu3[0][0]
# __________________________________________________________________________________________________
# fc5_class (QDense)              (None, 32)           544         class_relu4[0][0]
# __________________________________________________________________________________________________
# relu4 (QActivation)             (None, 32)           0           fc4[0][0]
# __________________________________________________________________________________________________
# class_relu5 (QActivation)       (None, 32)           0           fc5_class[0][0]
# __________________________________________________________________________________________________
# decoder_output (QDense)         (None, 64)           2112        relu4[0][0]
# __________________________________________________________________________________________________
# classifier_out (QDense)         (None, 10)           330         class_relu5[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 64)           0           decoder_output[0][0]
# __________________________________________________________________________________________________
# classifier_output (Activation)  (None, 10)           0           classifier_out[0][0]
# ==================================================================================================
# Total params: 6,268
# Trainable params: 6,268
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/40
#   2/235 [..............................] - ETA: 2:09 - loss: 0.4582 - sigmoid_loss: 0.2100 - classifier_output_loss: 2.3021 - sigmoid_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.0996WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0037s vs `on_train_batch_end` time: 1.1064s). Check your callbacks.
# 210/235 [=========================>....] - ETA: 0s - loss: 0.3441 - sigmoid_loss: 0.1295 - classifier_output_loss: 2.0063 - sigmoid_accuracy: 0.0673 - classifier_output_accuracy: 0.2105
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00001: val_loss improved from inf to 0.26571, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 0.26571, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3364 - sigmoid_loss: 0.1258 - classifier_output_loss: 1.9683 - sigmoid_accuracy: 0.0689 - classifier_output_accuracy: 0.2279 - val_loss: 0.2657 - val_sigmoid_loss: 0.0932 - val_classifier_output_loss: 1.5999 - val_sigmoid_accuracy: 0.0739 - val_classifier_output_accuracy: 0.3832
# Epoch 2/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.2411 - sigmoid_loss: 0.0904 - classifier_output_loss: 1.3731 - sigmoid_accuracy: 0.0689 - classifier_output_accuracy: 0.5105
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00002: val_loss improved from 0.26571 to 0.22065, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 0.26571 to 0.22065, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2399 - sigmoid_loss: 0.0902 - classifier_output_loss: 1.3625 - sigmoid_accuracy: 0.0679 - classifier_output_accuracy: 0.5147 - val_loss: 0.2207 - val_sigmoid_loss: 0.0870 - val_classifier_output_loss: 1.1915 - val_sigmoid_accuracy: 0.0488 - val_classifier_output_accuracy: 0.5912
# Epoch 3/40
# 219/235 [==========================>...] - ETA: 0s - loss: 0.2099 - sigmoid_loss: 0.0859 - classifier_output_loss: 1.0871 - sigmoid_accuracy: 0.0529 - classifier_output_accuracy: 0.6225
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00003: val_loss improved from 0.22065 to 0.19801, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 0.22065 to 0.19801, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00035: val_loss did not improve from 0.12857
#
# Epoch 00035: val_loss did not improve from 0.12857
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1287 - sigmoid_loss: 0.0753 - classifier_output_loss: 0.3552 - sigmoid_accuracy: 0.0552 - classifier_output_accuracy: 0.9078 - val_loss: 0.1296 - val_sigmoid_loss: 0.0753 - val_classifier_output_loss: 0.3645 - val_sigmoid_accuracy: 0.0457 - val_classifier_output_accuracy: 0.9096
# Epoch 36/40
# 209/235 [=========================>....] - ETA: 0s - loss: 0.1283 - sigmoid_loss: 0.0753 - classifier_output_loss: 0.3520 - sigmoid_accuracy: 0.0538 - classifier_output_accuracy: 0.9093
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00036: val_loss improved from 0.12857 to 0.12739, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00036: val_loss improved from 0.12857 to 0.12739, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1283 - sigmoid_loss: 0.0753 - classifier_output_loss: 0.3528 - sigmoid_accuracy: 0.0539 - classifier_output_accuracy: 0.9094 - val_loss: 0.1274 - val_sigmoid_loss: 0.0747 - val_classifier_output_loss: 0.3494 - val_sigmoid_accuracy: 0.0482 - val_classifier_output_accuracy: 0.9148
# Epoch 37/40
# 210/235 [=========================>....] - ETA: 0s - loss: 0.1279 - sigmoid_loss: 0.0751 - classifier_output_loss: 0.3505 - sigmoid_accuracy: 0.0528 - classifier_output_accuracy: 0.9096
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00037: val_loss did not improve from 0.12739
#
# Epoch 00037: val_loss did not improve from 0.12739
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1280 - sigmoid_loss: 0.0751 - classifier_output_loss: 0.3509 - sigmoid_accuracy: 0.0529 - classifier_output_accuracy: 0.9095 - val_loss: 0.1278 - val_sigmoid_loss: 0.0743 - val_classifier_output_loss: 0.3569 - val_sigmoid_accuracy: 0.0528 - val_classifier_output_accuracy: 0.9102
# Epoch 38/40
# 235/235 [==============================] - ETA: 0s - loss: 0.1282 - sigmoid_loss: 0.0751 - classifier_output_loss: 0.3532 - sigmoid_accuracy: 0.0556 - classifier_output_accuracy: 0.9089
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00038: val_loss did not improve from 0.12739
#
# Epoch 00038: val_loss did not improve from 0.12739
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1282 - sigmoid_loss: 0.0751 - classifier_output_loss: 0.3532 - sigmoid_accuracy: 0.0556 - classifier_output_accuracy: 0.9089 - val_loss: 0.1307 - val_sigmoid_loss: 0.0746 - val_classifier_output_loss: 0.3838 - val_sigmoid_accuracy: 0.0505 - val_classifier_output_accuracy: 0.9029
# Epoch 39/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.1276 - sigmoid_loss: 0.0751 - classifier_output_loss: 0.3484 - sigmoid_accuracy: 0.0545 - classifier_output_accuracy: 0.9105
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00039: val_loss improved from 0.12739 to 0.12699, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00039: val_loss improved from 0.12739 to 0.12699, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1276 - sigmoid_loss: 0.0751 - classifier_output_loss: 0.3486 - sigmoid_accuracy: 0.0545 - classifier_output_accuracy: 0.9106 - val_loss: 0.1270 - val_sigmoid_loss: 0.0745 - val_classifier_output_loss: 0.3481 - val_sigmoid_accuracy: 0.0508 - val_classifier_output_accuracy: 0.9105
# Epoch 40/40
# 209/235 [=========================>....] - ETA: 0s - loss: 0.1271 - sigmoid_loss: 0.0750 - classifier_output_loss: 0.3444 - sigmoid_accuracy: 0.0540 - classifier_output_accuracy: 0.9122
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00040: val_loss did not improve from 0.12699
#
# Epoch 00040: val_loss did not improve from 0.12699
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1271 - sigmoid_loss: 0.0750 - classifier_output_loss: 0.3448 - sigmoid_accuracy: 0.0540 - classifier_output_accuracy: 0.9123 - val_loss: 0.1284 - val_sigmoid_loss: 0.0745 - val_classifier_output_loss: 0.3622 - val_sigmoid_accuracy: 0.0490 - val_classifier_output_accuracy: 0.9109

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=True)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data(epochs=40,use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Compressed QAE with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="Compressed QAE with classifier")
# Out:
# Model: "functional_51"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 64)]         0
# __________________________________________________________________________________________________
# fc1 (QDense)                    (None, 32)           2080        encoder_input[0][0]
# __________________________________________________________________________________________________
# relu1 (QActivation)             (None, 32)           0           fc1[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_fc2_prun (P (None, 16)           1042        relu1[0][0]
# __________________________________________________________________________________________________
# relu2 (QActivation)             (None, 16)           0           prune_low_magnitude_fc2_prun[0][0
# __________________________________________________________________________________________________
# encoder_output (Dense)          (None, 2)            34          relu2[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_fc3 (PruneL (None, 16)           82          encoder_output[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_fc4_prunedc (None, 16)           82          encoder_output[0][0]
# __________________________________________________________________________________________________
# relu3 (QActivation)             (None, 16)           0           prune_low_magnitude_fc3[0][0]
# __________________________________________________________________________________________________
# prunclass_relu4 (QActivation)   (None, 16)           0           prune_low_magnitude_fc4_prunedcla
# __________________________________________________________________________________________________
# fc4 (QDense)                    (None, 32)           544         relu3[0][0]
# __________________________________________________________________________________________________
# fc5_class (QDense)              (None, 32)           544         prunclass_relu4[0][0]
# __________________________________________________________________________________________________
# relu4 (QActivation)             (None, 32)           0           fc4[0][0]
# __________________________________________________________________________________________________
# class_relu5 (QActivation)       (None, 32)           0           fc5_class[0][0]
# __________________________________________________________________________________________________
# decoder_output (QDense)         (None, 64)           2112        relu4[0][0]
# __________________________________________________________________________________________________
# classifier_out (QDense)         (None, 10)           330         class_relu5[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 64)           0           decoder_output[0][0]
# __________________________________________________________________________________________________
# classifier_output (Activation)  (None, 10)           0           classifier_out[0][0]
# ==================================================================================================
# Total params: 6,850
# Trainable params: 6,268
# Non-trainable params: 582
# __________________________________________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/40
#   2/235 [..............................] - ETA: 3:39 - loss: 0.4592 - sigmoid_loss: 0.2109 - classifier_output_loss: 2.3058 - sigmoid_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.0781WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0030s vs `on_train_batch_end` time: 1.8822s). Check your callbacks.
# 210/235 [=========================>....] - ETA: 0s - loss: 0.3485 - sigmoid_loss: 0.1254 - classifier_output_loss: 2.0964 - sigmoid_accuracy: 0.0363 - classifier_output_accuracy: 0.2169
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00001: val_loss improved from inf to 0.27006, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 0.27006, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3409 - sigmoid_loss: 0.1221 - classifier_output_loss: 2.0548 - sigmoid_accuracy: 0.0385 - classifier_output_accuracy: 0.2272 - val_loss: 0.2701 - val_sigmoid_loss: 0.0933 - val_classifier_output_loss: 1.6483 - val_sigmoid_accuracy: 0.0269 - val_classifier_output_accuracy: 0.3272
# Epoch 2/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.2478 - sigmoid_loss: 0.0900 - classifier_output_loss: 1.4549 - sigmoid_accuracy: 0.0366 - classifier_output_accuracy: 0.4017
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00002: val_loss improved from 0.27006 to 0.23289, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 0.27006 to 0.23289, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2478 - sigmoid_loss: 0.0900 - classifier_output_loss: 1.4547 - sigmoid_accuracy: 0.0366 - classifier_output_accuracy: 0.4019 - val_loss: 0.2329 - val_sigmoid_loss: 0.0870 - val_classifier_output_loss: 1.3306 - val_sigmoid_accuracy: 0.0383 - val_classifier_output_accuracy: 0.4666
# Epoch 3/40
# 213/235 [==========================>...] - ETA: 0s - loss: 0
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1345 - sigmoid_loss: 0.0776 - classifier_output_loss: 0.3963 - sigmoid_accuracy: 0.0649 - classifier_output_accuracy: 0.8965
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00036: val_loss improved from 0.13425 to 0.13365, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00036: val_loss improved from 0.13425 to 0.13365, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1345 - sigmoid_loss: 0.0776 - classifier_output_loss: 0.3962 - sigmoid_accuracy: 0.0649 - classifier_output_accuracy: 0.8964 - val_loss: 0.1337 - val_sigmoid_loss: 0.0769 - val_classifier_output_loss: 0.3950 - val_sigmoid_accuracy: 0.0502 - val_classifier_output_accuracy: 0.8992
# Epoch 37/40
# 211/235 [=========================>....] - ETA: 0s - loss: 0.1340 - sigmoid_loss: 0.0774 - classifier_output_loss: 0.3936 - sigmoid_accuracy: 0.0675 - classifier_output_accuracy: 0.8976
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00037: val_loss improved from 0.13365 to 0.13311, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00037: val_loss improved from 0.13365 to 0.13311, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1340 - sigmoid_loss: 0.0775 - classifier_output_loss: 0.3933 - sigmoid_accuracy: 0.0672 - classifier_output_accuracy: 0.8981 - val_loss: 0.1331 - val_sigmoid_loss: 0.0771 - val_classifier_output_loss: 0.3886 - val_sigmoid_accuracy: 0.0779 - val_classifier_output_accuracy: 0.9008
# Epoch 38/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.1334 - sigmoid_loss: 0.0775 - classifier_output_loss: 0.3872 - sigmoid_accuracy: 0.0646 - classifier_output_accuracy: 0.8990
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00038: val_loss did not improve from 0.13311
#
# Epoch 00038: val_loss did not improve from 0.13311
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1334 - sigmoid_loss: 0.0775 - classifier_output_loss: 0.3873 - sigmoid_accuracy: 0.0647 - classifier_output_accuracy: 0.8990 - val_loss: 0.1340 - val_sigmoid_loss: 0.0769 - val_classifier_output_loss: 0.3996 - val_sigmoid_accuracy: 0.0829 - val_classifier_output_accuracy: 0.8994
# Epoch 39/40
# 212/235 [==========================>...] - ETA: 0s - loss: 0.1332 - sigmoid_loss: 0.0776 - classifier_output_loss: 0.3856 - sigmoid_accuracy: 0.0663 - classifier_output_accuracy: 0.8993
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00039: val_loss did not improve from 0.13311
#
# Epoch 00039: val_loss did not improve from 0.13311
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1332 - sigmoid_loss: 0.0775 - classifier_output_loss: 0.3862 - sigmoid_accuracy: 0.0661 - classifier_output_accuracy: 0.8991 - val_loss: 0.1357 - val_sigmoid_loss: 0.0774 - val_classifier_output_loss: 0.4120 - val_sigmoid_accuracy: 0.0499 - val_classifier_output_accuracy: 0.8968
# Epoch 40/40
# 215/235 [==========================>...] - ETA: 0s - loss: 0.1334 - sigmoid_loss: 0.0775 - classifier_output_loss: 0.3892 - sigmoid_accuracy: 0.0672 - classifier_output_accuracy: 0.8983
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00040: val_loss did not improve from 0.13311
#
# Epoch 00040: val_loss did not improve from 0.13311
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1335 - sigmoid_loss: 0.0775 - classifier_output_loss: 0.3896 - sigmoid_accuracy: 0.0674 - classifier_output_accuracy: 0.8983 - val_loss: 0.1345 - val_sigmoid_loss: 0.0769 - val_classifier_output_loss: 0.4066 - val_sigmoid_accuracy: 0.0637 - val_classifier_output_accuracy: 0.8965
