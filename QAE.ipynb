# %%
import tensorflow as tf
from tensorflow.python.keras import Input
from tensorflow.python.keras.models import Model, Sequential
from tensorflow.python.keras.engine.keras_tensor import KerasTensor
from tensorflow.python.keras.engine.functional import Functional
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Activation
from tensorflow.python.keras.regularizers import l2
import os

from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning, prune_low_magnitude

from callbacks import all_callbacks
from tensorflow.keras.regularizers import l1

# %%
from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu
from tensorflow.quantization import quantize

# %% [markdown]
# ### Import the MNIST data class and call it.

# %% [markdown]
# Original dataset and modified dataset with modifiable resolution is shown below.

# %%
import MNIST_dataset as mnist
size_final = 28

data = mnist.MNISTData(size_initial=28, size_final=size_final, color_depth=8)
train= data.x_train
ax = plt.subplot(1, 1 , 1)

plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %%
import MNIST_dataset as mnist

#Choose the final size of your image dataset
size_final = 8

data_zoom = mnist.MNISTData(size_initial=20, size_final=size_final, color_depth=5, flat=True)
train= data_zoom.x_train
ax = plt.subplot(1, 1 , 1)

plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
class QAutoencoder:
    """Autoencoder Class"""

    def __init__(self, data: mnist.MNISTData, num_classes=10, pruned = False):
        self.x_train = data.x_train
        self.x_test = data.x_test
        self.y_train = data.y_train
        self.y_test = data.y_test

        self.num_classes = num_classes
        self.pruned = pruned
        self.input_shape = (self.x_train.shape[-1],)
        self.input = Input(shape=self.input_shape, name='encoder_input')
        self.latent_dim = 2

        self.encoder = None
        self.encoder_model = None
        self.decoder = None
        self.decoder_model = None
        self.latent_classifier = None
        self.autoencoder = None

        self.history = None

        self.pruning_params = {"pruning_schedule" : pruning_schedule.ConstantSparsity(0.8, begin_step=2000, end_step=10000, frequency=100)}
    
    def build_encoder(self):
        """Build your encoder architecture and store the output in self.encoder. 
        The final encoding dimension is 2."""


        """self.input = QDense( 64, input_shape = self.input_shape ,name='encoder_input',
                                kernel_quantizer=quantized_bits(16,0,alpha=1),
                                bias_quantizer=quantized_bits(16,0,alpha=1),
                                kernel_initializer='lecun_uniform')
        self.input = QActivation(activation=quantized_relu(18), name='relu0')(self.input)"""
        self.encoder = QDense(32,  name='fc1',
                        kernel_quantizer=quantized_bits(4,0, alpha=1),
                        bias_quantizer=quantized_bits(4,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.input)
        self.encoder = QActivation(activation=quantized_relu(4), name='relu1')(self.encoder)

        if self.pruned:
            self.encoder = prune_low_magnitude(QDense(16,  name='fc2_prun',
                        kernel_quantizer=quantized_bits(4, 0, alpha=1),
                        bias_quantizer=quantized_bits(4, 0, alpha=1),
                        kernel_initializer='lecun_uniform'), **self.pruning_params)(self.encoder) 
            self.encoder = QActivation(activation=quantized_relu(4), name='relu2')(self.encoder)
        
        if not self.pruned:
            self.encoder = QDense(16,  name='fc2',
                        kernel_quantizer=quantized_bits(4,0,alpha=1),
                        bias_quantizer=quantized_bits(4,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.encoder)
            self.encoder = QActivation(activation=quantized_relu(4), name='relu2')(self.encoder)
        
        self.encoder = Dense(self.latent_dim,  activation='relu', name = 'encoder_output')(self.encoder)

        #building a model for the encoder in order to be able to predict and plot the latent dimension
        self.encoder_model = Model(self.input, self.encoder, name='encoder')

    def build_decoder(self):
        """Build the decoder architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the decoder!")
           
        if self.pruned:
            self.decoder = prune_low_magnitude(QDense(16,  name='fc3',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0,alpha=1),
                        kernel_initializer='lecun_uniform'), **self.pruning_params)(self.encoder)
            self.decoder= QActivation(activation=quantized_relu(5,0), name='relu3')(self.decoder)

        if not self.pruned:
            self.decoder = QDense(16,  name='fc3',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.encoder)
            self.decoder=QActivation(activation=quantized_relu(5), name='relu3')(self.decoder)

        self.decoder = QDense(32,  name='fc4',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.decoder)
        self.decoder = QActivation(activation=quantized_relu(5), name='relu4')(self.decoder) 

        self.decoder = QDense(self.input_shape[0],name='decoder_output',
                        kernel_quantizer=quantized_bits(6,0,alpha=1),
                        bias_quantizer=quantized_bits(6,0, alpha=1),
                        kernel_initializer='lecun_uniform')(self.decoder)
        #self.decoder = Activation(activation='sigmoid', name='sigmoid')(self.decoder)
        self.decoder = QActivation(activation=quantized_relu(6, use_sigmoid=1), name='relu_decoder')(self.decoder) 

        
    def build_classifier(self):
        """ Building the classifier architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the classifier!")
        
        if self.pruned:
            self.latent_classifier = prune_low_magnitude(QDense(16,  name='fc4_prunedclass',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0,alpha=1),
                        kernel_initializer='lecun_uniform', 
                        kernel_regularizer=l1(0.0001)), **self.pruning_params)(self.encoder)
            self.latent_classifier = QActivation(activation=quantized_relu(5,0), name='prunclass_relu4')(self.latent_classifier)
        
        if not self.pruned:
            self.latent_classifier = QDense(16,  name='fc4_class',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0, alpha=1),
                        kernel_initializer='lecun_uniform',
                        kernel_regularizer=l1(0.0001))(self.encoder)
            self.latent_classifier=QActivation(activation=quantized_relu(5), name='class_relu4')(self.latent_classifier)

        self.latent_classifier = QDense(32,  name='fc5_class',
                        kernel_quantizer=quantized_bits(5,0,alpha=1),
                        bias_quantizer=quantized_bits(5,0, alpha=1),
                        kernel_initializer='lecun_uniform', 
                        kernel_regularizer=l1(0.0001))(self.latent_classifier)
        self.latent_classifier = QActivation(activation=quantized_relu(5), name='class_relu5')(self.latent_classifier)
        
        self.latent_classifier = QDense(self.num_classes,  name='classifier_out',
                        kernel_quantizer=quantized_bits(16,6,alpha=1),
                        bias_quantizer=quantized_bits(16,6, alpha=1),
                        kernel_initializer='lecun_uniform', 
                        kernel_regularizer=l1(0.0001))(self.latent_classifier)
        self.latent_classifier = Activation(activation='softmax', name = 'classifier_output')(self.latent_classifier)
        
    def build_autoencoder(self, use_latent_classifier=False):
        """ Build the whole autoencoder Model from self.encoder and self.decoder."""
        self.dir()
        
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the autoencoder!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")
        
        if use_latent_classifier:
            if self.latent_classifier is None:
                raise RuntimeError("If you want to use the option with the latent classifier, you have to build it "
                                   "beforehand!")
            self.autoencoder = Model(self.input, outputs=[self.decoder, self.latent_classifier])
            self.autoencoder.compile(loss=['mse', 'categorical_crossentropy'], loss_weights=[1, 0.1], optimizer='adam',
                                     metrics="accuracy")
            if not self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_model_w_classifier.h5')
            if self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_pruned_model_w_classifier.h5')
    
        else:
            self.autoencoder = Model(self.input, outputs=self.decoder, name = 'autoencoder')
            self.autoencoder.compile(loss='mse', optimizer='adam') 
            if not self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_model_wo_classifier.h5')
            if self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_pruned_model_wo_classifier.h5')
        self.autoencoder.summary()
        
    def fit_data(self, batch_size=256, epochs=30, use_latent_classifier=False):
        """Write the fit function for the autoencoder. 
        Storing the fit history in self.history to be able to plot the fitting scores."""
        
        callbacks = all_callbacks(stop_patience = 1000,        
                              lr_factor = 0.5,
                              lr_patience = 10,
                              lr_epsilon = 0.000001,
                              lr_cooldown = 2,
                              lr_minimum = 0.0000001,
                              outputDir = 'model/QAE_model/model_2')
        callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep()) 
        
        if use_latent_classifier:
            self.history = self.autoencoder.fit(self.x_train, [self.x_train, self.y_train],
                                                validation_data=(self.x_test, [self.x_test, self.y_test]),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True, callbacks=callbacks.callbacks)
            self.autoencoder = strip_pruning(self.autoencoder)
            if not self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_best_model_classifier.h5')
            if self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_pruned_best_model_classifier.h5')
        else:                         
            self.history = self.autoencoder.fit(self.x_train, self.x_train,
                                                validation_data=(self.x_test, self.x_test),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True, callbacks=callbacks.callbacks)  
            self.autoencoder = strip_pruning(self.autoencoder)
            if not self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_best_model.h5')
            if self.pruned:
                self.autoencoder.save('model/QAE_model/KERAS_check_pruned_best_model.h5')

        self.history = self.history.history

    def dir(self):
        """Creation of the folders path to store the results."""
        dir = os.path.join("images")
        if not os.path.exists(dir):
            os.mkdir(dir)
        dir2 = os.path.join("./images/QAE")
        if not os.path.exists(dir2):
            os.mkdir(dir2)
        dir3 = os.path.join("model")
        if not os.path.exists(dir3):
            os.mkdir(dir3)
        dir4 = os.path.join("./model/QAE_model")
        if not os.path.exists(dir4):
            os.mkdir(dir4)
        
    
    def plot_score(self, use_latent_classifier = False, model_name=None):
        """Plots the scores achieved during the fitting."""
        if use_latent_classifier is False:
            plt.plot(self.history['loss'])
            plt.plot(self.history['val_loss'])
            plt.ylabel('Model Accuracy')
        else:
            plt.plot(self.history['classifier_output_accuracy'])
            plt.plot(self.history['val_classifier_output_accuracy'])
            plt.ylabel('Classifier Accuracy')
        
        plt.xlabel('Epoch')        
        plt.legend(['Train', 'Test'], loc='best')
        plt.title('Accuracy of {model_name}'.format(model_name=model_name))
        
        plt.savefig('./images/QAE/Accuracy of {model_name}.png'.format(model_name=model_name))
        
        plt.show()

    def plot_latent_dimension(self, model_name = None):
        """Plots the latent dimension of the autoencoder."""
        prediction = self.encoder_model.predict(self.x_test)
        fig = plt.figure(figsize=(10, 10))
        fig.patch.set_facecolor("white")
        plt.scatter(prediction[:, 0], prediction[:, 1], c=np.argmax(self.y_test, axis=1), cmap="Set3")
        plt.colorbar()
        plt.title('Latent space {model_name}'.format(model_name=model_name))


        plt.savefig('./images/QAE/Latent dimension of {model_name}.png'.format(model_name=model_name))

        plt.show()

    def plot_reco(self, use_latent_classifier = False, model_name = None):
        """Plotting reconstructed images"""
        
        n = 6
        plt.figure(figsize=(10, 3))
        reco_imgs = self.autoencoder.predict(self.x_test)
        img_size = int(np.sqrt(self.input_shape[0]))

        
        if use_latent_classifier :
            raise RuntimeError("You are considering the autoencoder with classifier!")
        else:
        
            for i in range(n):
                # Display original MNIST
                ax = plt.subplot(2, n, i + 1)
                plt.imshow(self.x_test[i].reshape(img_size,img_size), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)

                # Display reconstructed MNIST            
                ax = plt.subplot(2, n, i + n + 1)
                plt.imshow(reco_imgs[i].reshape(img_size,img_size), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)
            
            plt.savefig('./images/QAE/reconstructed images{model_name}.png'.format(model_name=model_name))
            plt.show()
            
    def plot_latent(self):
        n = 6
        plt.figure(figsize=(10, 3))
        reco_imgs = self.encoder_model.predict(self.x_test)
        img_size = int(np.sqrt(self.input_shape[0]))

        ax = plt.subplot(1, 1, 1)
        plt.imshow(reco_imgs[1].reshape(2,1), cmap='gray_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        plt.show()

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = QAutoencoder(data_zoom, pruned=False)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("QAutoencoder without classifier")
network.plot_reco(model_name=" complete")
network.plot_score(use_latent_classifier=False, model_name="Autoencoder without classifier")
network.plot_latent()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 64)]              0
# _________________________________________________________________
# fc1 (QDense)                 (None, 32)                2080
# _________________________________________________________________
# relu1 (QActivation)          (None, 32)                0
# _________________________________________________________________
# fc2 (QDense)                 (None, 16)                528
# _________________________________________________________________
# relu2 (QActivation)          (None, 16)                0
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 34
# _________________________________________________________________
# fc3 (QDense)                 (None, 16)                48
# _________________________________________________________________
# relu3 (QActivation)          (None, 16)                0
# _________________________________________________________________
# fc4 (QDense)                 (None, 32)                544
# _________________________________________________________________
# relu4 (QActivation)          (None, 32)                0
# _________________________________________________________________
# decoder_output (QDense)      (None, 64)                2112
# _________________________________________________________________
# relu_decoder (QActivation)   (None, 64)                0
# =================================================================
# Total params: 5,346
# Trainable params: 5,346
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/40
#   2/235 [..............................] - ETA: 5:28 - loss: 0.1560WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_end` time: 2.8131s). Check your callbacks.
# 222/235 [===========================>..] - ETA: 0s - loss: 0.1182
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00001: val_loss improved from inf to 0.10455, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 0.10455, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 5s 21ms/step - loss: 0.1175 - val_loss: 0.1046
# Epoch 2/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0969
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00002: val_loss improved from 0.10455 to 0.09105, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 0.10455 to 0.09105, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0967 - val_loss: 0.0910
# Epoch 3/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0858
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00003: val_loss improved from 0.09105 to 0.08318, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 0.09105 to 0.08318, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0858 - val_loss: 0.0832
# Epoch 4/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0822
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00004: val_loss improved from 0.08318 to 0.08041, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.08318 to 0.08041, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0822 - val_loss: 0.0804
# Epoch 5/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0799
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00005: val_loss improved from 0.08041 to 0.07838, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00005: val_loss improved from 0.08041 to 0.07838, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0798 - val_loss: 0.0784
# Epoch 6/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0781
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00006: val_loss improved from 0.07838 to 0.07740, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00006: val_loss improved from 0.07838 to 0.07740, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0781 - val_loss: 0.0774
# Epoch 7/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0766
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00007: val_loss improved from 0.07740 to 0.07559, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00007: val_loss improved from 0.07740 to 0.07559, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0766 - val_loss: 0.0756
# Epoch 8/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.0756
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00008: val_loss improved from 0.07559 to 0.07437, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00008: val_loss improved from 0.07559 to 0.07437, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0755 - val_loss: 0.0744
# Epoch 9/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0749
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00009: val_loss improved from 0.07437 to 0.07430, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00009: val_loss improved from 0.07437 to 0.07430, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0749 - val_loss: 0.0743
# Epoch 10/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0743
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00010: val_loss improved from 0.07430 to 0.07425, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00010: val_loss improved from 0.07430 to 0.07425, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0743 - val_loss: 0.0743
# Epoch 11/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0738
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00011: val_loss improved from 0.07425 to 0.07370, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00011: val_loss improved from 0.07425 to 0.07370, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0739 - val_loss: 0.0737
# Epoch 12/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0736
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00012: val_loss improved from 0.07370 to 0.07338, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00012: val_loss improved from 0.07370 to 0.07338, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0736 - val_loss: 0.0734
# Epoch 13/40
# 219/235 [==========================>...] - ETA: 0s - loss: 0.0730
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00013: val_loss improved from 0.07338 to 0.07276, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00013: val_loss improved from 0.07338 to 0.07276, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0730 - val_loss: 0.0728
# Epoch 14/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.0727
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00014: val_loss did not improve from 0.07276
#
# Epoch 00014: val_loss did not improve from 0.07276
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0727 - val_loss: 0.0729
# Epoch 15/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0723
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00015: val_loss improved from 0.07276 to 0.07169, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00015: val_loss improved from 0.07276 to 0.07169, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0723 - val_loss: 0.0717
# Epoch 16/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0719
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00016: val_loss improved from 0.07169 to 0.07156, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00016: val_loss improved from 0.07169 to 0.07156, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0719 - val_loss: 0.0716
# Epoch 17/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0712
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00017: val_loss improved from 0.07156 to 0.06926, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00017: val_loss improved from 0.07156 to 0.06926, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0711 - val_loss: 0.0693
# Epoch 18/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0691
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00018: val_loss improved from 0.06926 to 0.06885, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 0.06926 to 0.06885, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0690 - val_loss: 0.0688
# Epoch 19/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0687
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00019: val_loss improved from 0.06885 to 0.06864, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00019: val_loss improved from 0.06885 to 0.06864, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0687 - val_loss: 0.0686
# Epoch 20/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0684
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00020: val_loss improved from 0.06864 to 0.06811, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00020: val_loss improved from 0.06864 to 0.06811, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0684 - val_loss: 0.0681
# Epoch 21/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0681
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00021: val_loss improved from 0.06811 to 0.06781, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00021: val_loss improved from 0.06811 to 0.06781, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0681 - val_loss: 0.0678
# Epoch 22/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0679
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00022: val_loss improved from 0.06781 to 0.06755, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00022: val_loss improved from 0.06781 to 0.06755, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0679 - val_loss: 0.0675
# Epoch 23/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0676
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00023: val_loss did not improve from 0.06755
#
# Epoch 00023: val_loss did not improve from 0.06755
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0676 - val_loss: 0.0688
# Epoch 24/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0674
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00024: val_loss improved from 0.06755 to 0.06714, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00024: val_loss improved from 0.06755 to 0.06714, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0675 - val_loss: 0.0671
# Epoch 25/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.0673
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00025: val_loss improved from 0.06714 to 0.06691, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00025: val_loss improved from 0.06714 to 0.06691, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0673 - val_loss: 0.0669
# Epoch 26/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0671
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00026: val_loss did not improve from 0.06691
#
# Epoch 00026: val_loss did not improve from 0.06691
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0672 - val_loss: 0.0676
# Epoch 27/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.0669
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00027: val_loss improved from 0.06691 to 0.06685, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00027: val_loss improved from 0.06691 to 0.06685, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0669 - val_loss: 0.0669
# Epoch 28/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.0667
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00028: val_loss improved from 0.06685 to 0.06648, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.06685 to 0.06648, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0667 - val_loss: 0.0665
# Epoch 29/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0667
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00029: val_loss did not improve from 0.06648
#
# Epoch 00029: val_loss did not improve from 0.06648
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0666 - val_loss: 0.0666
# Epoch 30/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0666
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00030: val_loss did not improve from 0.06648
#
# Epoch 00030: val_loss did not improve from 0.06648
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0666 - val_loss: 0.0669
# Epoch 31/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0665
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00031: val_loss did not improve from 0.06648
#
# Epoch 00031: val_loss did not improve from 0.06648
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0665 - val_loss: 0.0667
# Epoch 32/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0666
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00032: val_loss did not improve from 0.06648
#
# Epoch 00032: val_loss did not improve from 0.06648
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0666 - val_loss: 0.0668
# Epoch 33/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0665
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00033: val_loss improved from 0.06648 to 0.06606, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00033: val_loss improved from 0.06648 to 0.06606, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0665 - val_loss: 0.0661
# Epoch 34/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0663
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00034: val_loss did not improve from 0.06606
#
# Epoch 00034: val_loss did not improve from 0.06606
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0663 - val_loss: 0.0664
# Epoch 35/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0662
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00035: val_loss did not improve from 0.06606
#
# Epoch 00035: val_loss did not improve from 0.06606
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0662 - val_loss: 0.0663
# Epoch 36/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0659
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00036: val_loss did not improve from 0.06606
#
# Epoch 00036: val_loss did not improve from 0.06606
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0659 - val_loss: 0.0669
# Epoch 37/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0659
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00037: val_loss did not improve from 0.06606
#
# Epoch 00037: val_loss did not improve from 0.06606
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0659 - val_loss: 0.0661
# Epoch 38/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0658
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00038: val_loss did not improve from 0.06606
#
# Epoch 00038: val_loss did not improve from 0.06606
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0658 - val_loss: 0.0663
# Epoch 39/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0658
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00039: val_loss improved from 0.06606 to 0.06540, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00039: val_loss improved from 0.06606 to 0.06540, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0658 - val_loss: 0.0654
# Epoch 40/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0657
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00040: val_loss did not improve from 0.06540
#
# Epoch 00040: val_loss did not improve from 0.06540
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0657 - val_loss: 0.0656

# %%
network = QAutoencoder(data_zoom, pruned=True)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("Compressed QAE without classifier")
network.plot_reco(model_name=" compressed")
network.plot_score(use_latent_classifier=False,model_name="Compressed QAE without classifier")
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 64)]              0
# _________________________________________________________________
# fc1 (QDense)                 (None, 32)                2080
# _________________________________________________________________
# relu1 (QActivation)          (None, 32)                0
# _________________________________________________________________
# prune_low_magnitude_fc2_prun (None, 16)                1042
# _________________________________________________________________
# relu2 (QActivation)          (None, 16)                0
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 34
# _________________________________________________________________
# prune_low_magnitude_fc3 (Pru (None, 16)                82
# _________________________________________________________________
# relu3 (QActivation)          (None, 16)                0
# _________________________________________________________________
# fc4 (QDense)                 (None, 32)                544
# _________________________________________________________________
# relu4 (QActivation)          (None, 32)                0
# _________________________________________________________________
# decoder_output (QDense)      (None, 64)                2112
# _________________________________________________________________
# relu_decoder (QActivation)   (None, 64)                0
# =================================================================
# Total params: 5,894
# Trainable params: 5,346
# Non-trainable params: 548
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/40
#   2/235 [..............................] - ETA: 6:53 - loss: 0.1657WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0037s vs `on_train_batch_end` time: 3.5442s). Check your callbacks.
# 230/235 [============================>.] - ETA: 0s - loss: 0.1159
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00001: val_loss improved from inf to 0.10005, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 0.10005, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 25ms/step - loss: 0.1156 - val_loss: 0.1000
# Epoch 2/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0927
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00002: val_loss improved from 0.10005 to 0.08256, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 0.10005 to 0.08256, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0922 - val_loss: 0.0826
# Epoch 3/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.0807
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00003: val_loss improved from 0.08256 to 0.07941, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 0.08256 to 0.07941, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0807 - val_loss: 0.0794
# Epoch 4/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0784
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00004: val_loss improved from 0.07941 to 0.07770, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.07941 to 0.07770, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0784 - val_loss: 0.0777
# Epoch 5/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0771
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00005: val_loss improved from 0.07770 to 0.07601, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00005: val_loss improved from 0.07770 to 0.07601, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0771 - val_loss: 0.0760
# Epoch 6/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.0760
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00006: val_loss improved from 0.07601 to 0.07553, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00006: val_loss improved from 0.07601 to 0.07553, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0760 - val_loss: 0.0755
# Epoch 7/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0750
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00007: val_loss improved from 0.07553 to 0.07431, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00007: val_loss improved from 0.07553 to 0.07431, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0750 - val_loss: 0.0743
# Epoch 8/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0742
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00008: val_loss improved from 0.07431 to 0.07336, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00008: val_loss improved from 0.07431 to 0.07336, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0742 - val_loss: 0.0734
# Epoch 9/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0825
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00009: val_loss did not improve from 0.07336
#
# Epoch 00009: val_loss did not improve from 0.07336
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0825 - val_loss: 0.0826
# Epoch 10/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0808
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00010: val_loss did not improve from 0.07336
#
# Epoch 00010: val_loss did not improve from 0.07336
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0808 - val_loss: 0.0791
# Epoch 11/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0788
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00011: val_loss did not improve from 0.07336
#
# Epoch 00011: val_loss did not improve from 0.07336
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0788 - val_loss: 0.0776
# Epoch 12/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0778
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00012: val_loss did not improve from 0.07336
#
# Epoch 00012: val_loss did not improve from 0.07336
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0777 - val_loss: 0.0780
# Epoch 13/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.0766
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00013: val_loss did not improve from 0.07336
#
# Epoch 00013: val_loss did not improve from 0.07336
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0765 - val_loss: 0.0755
# Epoch 14/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0757
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00014: val_loss did not improve from 0.07336
#
# Epoch 00014: val_loss did not improve from 0.07336
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0757 - val_loss: 0.0750
# Epoch 15/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0751
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00015: val_loss did not improve from 0.07336
#
# Epoch 00015: val_loss did not improve from 0.07336
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0750 - val_loss: 0.0739
# Epoch 16/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0742
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00016: val_loss improved from 0.07336 to 0.07333, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00016: val_loss improved from 0.07336 to 0.07333, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0741 - val_loss: 0.0733
# Epoch 17/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0737
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00017: val_loss improved from 0.07333 to 0.07288, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00017: val_loss improved from 0.07333 to 0.07288, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0737 - val_loss: 0.0729
# Epoch 18/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0734
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00018: val_loss did not improve from 0.07288
#
# Epoch 00018: val_loss did not improve from 0.07288
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0734 - val_loss: 0.0746
# Epoch 19/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0731
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00019: val_loss did not improve from 0.07288
#
# Epoch 00019: val_loss did not improve from 0.07288
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0731 - val_loss: 0.0739
# Epoch 20/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0730
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00020: val_loss did not improve from 0.07288
#
# Epoch 00020: val_loss did not improve from 0.07288
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0730 - val_loss: 0.0730
# Epoch 21/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0729
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00021: val_loss improved from 0.07288 to 0.07233, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00021: val_loss improved from 0.07288 to 0.07233, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0729 - val_loss: 0.0723
# Epoch 22/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0724
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00022: val_loss did not improve from 0.07233
#
# Epoch 00022: val_loss did not improve from 0.07233
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0724 - val_loss: 0.0739
# Epoch 23/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0722
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00023: val_loss improved from 0.07233 to 0.07172, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 0.07233 to 0.07172, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0722 - val_loss: 0.0717
# Epoch 24/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0722
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00024: val_loss did not improve from 0.07172
#
# Epoch 00024: val_loss did not improve from 0.07172
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0722 - val_loss: 0.0722
# Epoch 25/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0722
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00025: val_loss did not improve from 0.07172
#
# Epoch 00025: val_loss did not improve from 0.07172
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0721 - val_loss: 0.0718
# Epoch 26/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0719
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00026: val_loss improved from 0.07172 to 0.07143, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00026: val_loss improved from 0.07172 to 0.07143, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0719 - val_loss: 0.0714
# Epoch 27/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0717
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00027: val_loss did not improve from 0.07143
#
# Epoch 00027: val_loss did not improve from 0.07143
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0717 - val_loss: 0.0714
# Epoch 28/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0717
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00028: val_loss improved from 0.07143 to 0.07107, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.07143 to 0.07107, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0716 - val_loss: 0.0711
# Epoch 29/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0717
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00029: val_loss improved from 0.07107 to 0.07101, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00029: val_loss improved from 0.07107 to 0.07101, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0718 - val_loss: 0.0710
# Epoch 30/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0715
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00030: val_loss did not improve from 0.07101
#
# Epoch 00030: val_loss did not improve from 0.07101
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0715 - val_loss: 0.0712
# Epoch 31/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0713
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00031: val_loss did not improve from 0.07101
#
# Epoch 00031: val_loss did not improve from 0.07101
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0713 - val_loss: 0.0713
# Epoch 32/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0712
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00032: val_loss did not improve from 0.07101
#
# Epoch 00032: val_loss did not improve from 0.07101
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0712 - val_loss: 0.0719
# Epoch 33/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0711
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00033: val_loss improved from 0.07101 to 0.07060, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00033: val_loss improved from 0.07101 to 0.07060, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0711 - val_loss: 0.0706
# Epoch 34/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0710
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00034: val_loss did not improve from 0.07060
#
# Epoch 00034: val_loss did not improve from 0.07060
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0709 - val_loss: 0.0715
# Epoch 35/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.0708
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00035: val_loss did not improve from 0.07060
#
# Epoch 00035: val_loss did not improve from 0.07060
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0708 - val_loss: 0.0708
# Epoch 36/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0708
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00036: val_loss did not improve from 0.07060
#
# Epoch 00036: val_loss did not improve from 0.07060
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0708 - val_loss: 0.0709
# Epoch 37/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0706
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00037: val_loss did not improve from 0.07060
#
# Epoch 00037: val_loss did not improve from 0.07060
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0705 - val_loss: 0.0707
# Epoch 38/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0704
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00038: val_loss improved from 0.07060 to 0.06976, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00038: val_loss improved from 0.07060 to 0.06976, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0704 - val_loss: 0.0698
# Epoch 39/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0700
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00039: val_loss improved from 0.06976 to 0.06948, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00039: val_loss improved from 0.06976 to 0.06948, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0700 - val_loss: 0.0695
# Epoch 40/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0699
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00040: val_loss did not improve from 0.06948
#
# Epoch 00040: val_loss did not improve from 0.06948
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0699 - val_loss: 0.0701

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=False)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data( batch_size=256,epochs=40, use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("QAutoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="QAutoencoder with classifier")
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 64)]         0
# __________________________________________________________________________________________________
# fc1 (QDense)                    (None, 32)           2080        encoder_input[0][0]
# __________________________________________________________________________________________________
# relu1 (QActivation)             (None, 32)           0           fc1[0][0]
# __________________________________________________________________________________________________
# fc2 (QDense)                    (None, 16)           528         relu1[0][0]
# __________________________________________________________________________________________________
# relu2 (QActivation)             (None, 16)           0           fc2[0][0]
# __________________________________________________________________________________________________
# encoder_output (Dense)          (None, 2)            34          relu2[0][0]
# __________________________________________________________________________________________________
# fc3 (QDense)                    (None, 16)           48          encoder_output[0][0]
# __________________________________________________________________________________________________
# fc4_class (QDense)              (None, 16)           48          encoder_output[0][0]
# __________________________________________________________________________________________________
# relu3 (QActivation)             (None, 16)           0           fc3[0][0]
# __________________________________________________________________________________________________
# class_relu4 (QActivation)       (None, 16)           0           fc4_class[0][0]
# __________________________________________________________________________________________________
# fc4 (QDense)                    (None, 32)           544         relu3[0][0]
# __________________________________________________________________________________________________
# fc5_class (QDense)              (None, 32)           544         class_relu4[0][0]
# __________________________________________________________________________________________________
# relu4 (QActivation)             (None, 32)           0           fc4[0][0]
# __________________________________________________________________________________________________
# class_relu5 (QActivation)       (None, 32)           0           fc5_class[0][0]
# __________________________________________________________________________________________________
# decoder_output (QDense)         (None, 64)           2112        relu4[0][0]
# __________________________________________________________________________________________________
# classifier_out (QDense)         (None, 10)           330         class_relu5[0][0]
# __________________________________________________________________________________________________
# relu_decoder (QActivation)      (None, 64)           0           decoder_output[0][0]
# __________________________________________________________________________________________________
# classifier_output (Activation)  (None, 10)           0           classifier_out[0][0]
# ==================================================================================================
# Total params: 6,268
# Trainable params: 6,268
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/40
#   2/235 [..............................] - ETA: 7:20 - loss: 0.4133 - relu_decoder_loss: 0.1646 - classifier_output_loss: 2.3082 - relu_decoder_accuracy: 0.0098 - classifier_output_accuracy: 0.1113WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0060s vs `on_train_batch_end` time: 3.7782s). Check your callbacks.
# 230/235 [============================>.] - ETA: 0s - loss: 0.3385 - relu_decoder_loss: 0.1169 - classifier_output_loss: 2.0855 - relu_decoder_accuracy: 0.0407 - classifier_output_accuracy: 0.2476
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00001: val_loss improved from inf to 0.27675, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 0.27675, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.3375 - relu_decoder_loss: 0.1166 - classifier_output_loss: 2.0782 - relu_decoder_accuracy: 0.0405 - classifier_output_accuracy: 0.2498 - val_loss: 0.2768 - val_relu_decoder_loss: 0.1003 - val_classifier_output_loss: 1.6487 - val_relu_decoder_accuracy: 0.0388 - val_classifier_output_accuracy: 0.3772
# Epoch 2/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.2437 - relu_decoder_loss: 0.0971 - classifier_output_loss: 1.3364 - relu_decoder_accuracy: 0.0299 - classifier_output_accuracy: 0.5130
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00002: val_loss improved from 0.27675 to 0.22130, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 0.27675 to 0.22130, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2437 - relu_decoder_loss: 0.0971 - classifier_output_loss: 1.3360 - relu_decoder_accuracy: 0.0299 - classifier_output_accuracy: 0.5131 - val_loss: 0.2213 - val_relu_decoder_loss: 0.0959 - val_classifier_output_loss: 1.1103 - val_relu_decoder_accuracy: 0.0236 - val_classifier_output_accuracy: 0.6161
# Epoch 3/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.2085 - relu_decoder_loss: 0.0948 - classifier_output_loss: 0.9824 - relu_decoder_accuracy: 0.0343 - classifier_output_accuracy: 0.6811
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00003: val_loss improved from 0.22130 to 0.19746, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 0.22130 to 0.19746, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2084 - relu_decoder_loss: 0.0948 - classifier_output_loss: 0.9821 - relu_decoder_accuracy: 0.0344 - classifier_output_accuracy: 0.6812 - val_loss: 0.1975 - val_relu_decoder_loss: 0.0936 - val_classifier_output_loss: 0.8743 - val_relu_decoder_accuracy: 0.0375 - val_classifier_output_accuracy: 0.7148
# Epoch 4/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.1906 - relu_decoder_loss: 0.0917 - classifier_output_loss: 0.8186 - relu_decoder_accuracy: 0.0463 - classifier_output_accuracy: 0.7419
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00004: val_loss improved from 0.19746 to 0.18391, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.19746 to 0.18391, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1904 - relu_decoder_loss: 0.0916 - classifier_output_loss: 0.8177 - relu_decoder_accuracy: 0.0464 - classifier_output_accuracy: 0.7421 - val_loss: 0.1839 - val_relu_decoder_loss: 0.0898 - val_classifier_output_loss: 0.7654 - val_relu_decoder_accuracy: 0.0373 - val_classifier_output_accuracy: 0.7564
# Epoch 5/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1803 - relu_decoder_loss: 0.0897 - classifier_output_loss: 0.7267 - relu_decoder_accuracy: 0.0470 - classifier_output_accuracy: 0.7757
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00005: val_loss improved from 0.18391 to 0.17649, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00005: val_loss improved from 0.18391 to 0.17649, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1801 - relu_decoder_loss: 0.0897 - classifier_output_loss: 0.7255 - relu_decoder_accuracy: 0.0469 - classifier_output_accuracy: 0.7772 - val_loss: 0.1765 - val_relu_decoder_loss: 0.0892 - val_classifier_output_loss: 0.6903 - val_relu_decoder_accuracy: 0.0462 - val_classifier_output_accuracy: 0.7831
# Epoch 6/40
# 235/235 [==============================] - ETA: 0s - loss: 0.1728 - relu_decoder_loss: 0.0890 - classifier_output_loss: 0.6525 - relu_decoder_accuracy: 0.0493 - classifier_output_accuracy: 0.8202
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00006: val_loss improved from 0.17649 to 0.16669, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00006: val_loss improved from 0.17649 to 0.16669, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1728 - relu_decoder_loss: 0.0890 - classifier_output_loss: 0.6525 - relu_decoder_accuracy: 0.0493 - classifier_output_accuracy: 0.8202 - val_loss: 0.1667 - val_relu_decoder_loss: 0.0883 - val_classifier_output_loss: 0.5947 - val_relu_decoder_accuracy: 0.0419 - val_classifier_output_accuracy: 0.8509
# Epoch 7/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.1645 - relu_decoder_loss: 0.0869 - classifier_output_loss: 0.5843 - relu_decoder_accuracy: 0.0493 - classifier_output_accuracy: 0.8499
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00007: val_loss improved from 0.16669 to 0.15871, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00007: val_loss improved from 0.16669 to 0.15871, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1645 - relu_decoder_loss: 0.0869 - classifier_output_loss: 0.5843 - relu_decoder_accuracy: 0.0493 - classifier_output_accuracy: 0.8498 - val_loss: 0.1587 - val_relu_decoder_loss: 0.0852 - val_classifier_output_loss: 0.5414 - val_relu_decoder_accuracy: 0.0414 - val_classifier_output_accuracy: 0.8666
# Epoch 8/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1592 - relu_decoder_loss: 0.0853 - classifier_output_loss: 0.5428 - relu_decoder_accuracy: 0.0489 - classifier_output_accuracy: 0.8597
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00008: val_loss did not improve from 0.15871
#
# Epoch 00008: val_loss did not improve from 0.15871
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1591 - relu_decoder_loss: 0.0853 - classifier_output_loss: 0.5425 - relu_decoder_accuracy: 0.0489 - classifier_output_accuracy: 0.8601 - val_loss: 0.1590 - val_relu_decoder_loss: 0.0850 - val_classifier_output_loss: 0.5437 - val_relu_decoder_accuracy: 0.0504 - val_classifier_output_accuracy: 0.8564
# Epoch 9/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1556 - relu_decoder_loss: 0.0848 - classifier_output_loss: 0.5111 - relu_decoder_accuracy: 0.0499 - classifier_output_accuracy: 0.8708
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00009: val_loss improved from 0.15871 to 0.15344, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00009: val_loss improved from 0.15871 to 0.15344, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1557 - relu_decoder_loss: 0.0849 - classifier_output_loss: 0.5120 - relu_decoder_accuracy: 0.0499 - classifier_output_accuracy: 0.8706 - val_loss: 0.1534 - val_relu_decoder_loss: 0.0843 - val_classifier_output_loss: 0.4939 - val_relu_decoder_accuracy: 0.0376 - val_classifier_output_accuracy: 0.8797
# Epoch 10/40
# 235/235 [==============================] - ETA: 0s - loss: 0.1524 - relu_decoder_loss: 0.0845 - classifier_output_loss: 0.4814 - relu_decoder_accuracy: 0.0497 - classifier_output_accuracy: 0.8786
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00010: val_loss improved from 0.15344 to 0.15214, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00010: val_loss improved from 0.15344 to 0.15214, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1524 - relu_decoder_loss: 0.0845 - classifier_output_loss: 0.4814 - relu_decoder_accuracy: 0.0497 - classifier_output_accuracy: 0.8786 - val_loss: 0.1521 - val_relu_decoder_loss: 0.0843 - val_classifier_output_loss: 0.4815 - val_relu_decoder_accuracy: 0.0409 - val_classifier_output_accuracy: 0.8842
# Epoch 11/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.1504 - relu_decoder_loss: 0.0844 - classifier_output_loss: 0.4630 - relu_decoder_accuracy: 0.0490 - classifier_output_accuracy: 0.8838
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00011: val_loss did not improve from 0.15214
#
# Epoch 00011: val_loss did not improve from 0.15214
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1504 - relu_decoder_loss: 0.0844 - classifier_output_loss: 0.4631 - relu_decoder_accuracy: 0.0490 - classifier_output_accuracy: 0.8838 - val_loss: 0.1534 - val_relu_decoder_loss: 0.0842 - val_classifier_output_loss: 0.4946 - val_relu_decoder_accuracy: 0.0467 - val_classifier_output_accuracy: 0.8719
# Epoch 12/40
# 235/235 [==============================] - ETA: 0s - loss: 0.1485 - relu_decoder_loss: 0.0843 - classifier_output_loss: 0.4456 - relu_decoder_accuracy: 0.0499 - classifier_output_accuracy: 0.8882
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00012: val_loss improved from 0.15214 to 0.14838, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00012: val_loss improved from 0.15214 to 0.14838, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1485 - relu_decoder_loss: 0.0843 - classifier_output_loss: 0.4456 - relu_decoder_accuracy: 0.0499 - classifier_output_accuracy: 0.8882 - val_loss: 0.1484 - val_relu_decoder_loss: 0.0840 - val_classifier_output_loss: 0.4472 - val_relu_decoder_accuracy: 0.0414 - val_classifier_output_accuracy: 0.8866
# Epoch 13/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.1465 - relu_decoder_loss: 0.0842 - classifier_output_loss: 0.4265 - relu_decoder_accuracy: 0.0491 - classifier_output_accuracy: 0.8937
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00013: val_loss improved from 0.14838 to 0.14495, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00013: val_loss improved from 0.14838 to 0.14495, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1464 - relu_decoder_loss: 0.0842 - classifier_output_loss: 0.4262 - relu_decoder_accuracy: 0.0494 - classifier_output_accuracy: 0.8937 - val_loss: 0.1450 - val_relu_decoder_loss: 0.0836 - val_classifier_output_loss: 0.4175 - val_relu_decoder_accuracy: 0.0429 - val_classifier_output_accuracy: 0.8995
# Epoch 14/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1452 - relu_decoder_loss: 0.0840 - classifier_output_loss: 0.4171 - relu_decoder_accuracy: 0.0494 - classifier_output_accuracy: 0.8958
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00014: val_loss did not improve from 0.14495
#
# Epoch 00014: val_loss did not improve from 0.14495
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1453 - relu_decoder_loss: 0.0840 - classifier_output_loss: 0.4183 - relu_decoder_accuracy: 0.0497 - classifier_output_accuracy: 0.8951 - val_loss: 0.1455 - val_relu_decoder_loss: 0.0836 - val_classifier_output_loss: 0.4250 - val_relu_decoder_accuracy: 0.0488 - val_classifier_output_accuracy: 0.8945
# Epoch 15/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1443 - relu_decoder_loss: 0.0839 - classifier_output_loss: 0.4106 - relu_decoder_accuracy: 0.0495 - classifier_output_accuracy: 0.8972
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00015: val_loss improved from 0.14495 to 0.14362, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00015: val_loss improved from 0.14495 to 0.14362, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1443 - relu_decoder_loss: 0.0839 - classifier_output_loss: 0.4108 - relu_decoder_accuracy: 0.0496 - classifier_output_accuracy: 0.8975 - val_loss: 0.1436 - val_relu_decoder_loss: 0.0835 - val_classifier_output_loss: 0.4078 - val_relu_decoder_accuracy: 0.0477 - val_classifier_output_accuracy: 0.9007
# Epoch 16/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1426 - relu_decoder_loss: 0.0838 - classifier_output_loss: 0.3954 - relu_decoder_accuracy: 0.0509 - classifier_output_accuracy: 0.9020
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00016: val_loss did not improve from 0.14362
#
# Epoch 00016: val_loss did not improve from 0.14362
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1427 - relu_decoder_loss: 0.0838 - classifier_output_loss: 0.3965 - relu_decoder_accuracy: 0.0505 - classifier_output_accuracy: 0.9016 - val_loss: 0.1472 - val_relu_decoder_loss: 0.0836 - val_classifier_output_loss: 0.4435 - val_relu_decoder_accuracy: 0.0496 - val_classifier_output_accuracy: 0.8876
# Epoch 17/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.1423 - relu_decoder_loss: 0.0838 - classifier_output_loss: 0.3939 - relu_decoder_accuracy: 0.0502 - classifier_output_accuracy: 0.9008
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00017: val_loss did not improve from 0.14362
#
# Epoch 00017: val_loss did not improve from 0.14362
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1423 - relu_decoder_loss: 0.0838 - classifier_output_loss: 0.3938 - relu_decoder_accuracy: 0.0503 - classifier_output_accuracy: 0.9008 - val_loss: 0.1454 - val_relu_decoder_loss: 0.0836 - val_classifier_output_loss: 0.4268 - val_relu_decoder_accuracy: 0.0443 - val_classifier_output_accuracy: 0.8912
# Epoch 18/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.1410 - relu_decoder_loss: 0.0836 - classifier_output_loss: 0.3828 - relu_decoder_accuracy: 0.0497 - classifier_output_accuracy: 0.9037
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00018: val_loss improved from 0.14362 to 0.14158, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 0.14362 to 0.14158, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1409 - relu_decoder_loss: 0.0836 - classifier_output_loss: 0.3827 - relu_decoder_accuracy: 0.0497 - classifier_output_accuracy: 0.9038 - val_loss: 0.1416 - val_relu_decoder_loss: 0.0831 - val_classifier_output_loss: 0.3948 - val_relu_decoder_accuracy: 0.0449 - val_classifier_output_accuracy: 0.9057
# Epoch 19/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1405 - relu_decoder_loss: 0.0834 - classifier_output_loss: 0.3815 - relu_decoder_accuracy: 0.0513 - classifier_output_accuracy: 0.9047
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00019: val_loss improved from 0.14158 to 0.14062, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00019: val_loss improved from 0.14158 to 0.14062, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1404 - relu_decoder_loss: 0.0834 - classifier_output_loss: 0.3807 - relu_decoder_accuracy: 0.0512 - classifier_output_accuracy: 0.9050 - val_loss: 0.1406 - val_relu_decoder_loss: 0.0828 - val_classifier_output_loss: 0.3890 - val_relu_decoder_accuracy: 0.0451 - val_classifier_output_accuracy: 0.9053
# Epoch 20/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.1391 - relu_decoder_loss: 0.0833 - classifier_output_loss: 0.3700 - relu_decoder_accuracy: 0.0514 - classifier_output_accuracy: 0.9081
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00020: val_loss improved from 0.14062 to 0.13906, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00020: val_loss improved from 0.14062 to 0.13906, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1390 - relu_decoder_loss: 0.0832 - classifier_output_loss: 0.3693 - relu_decoder_accuracy: 0.0515 - classifier_output_accuracy: 0.9082 - val_loss: 0.1391 - val_relu_decoder_loss: 0.0828 - val_classifier_output_loss: 0.3750 - val_relu_decoder_accuracy: 0.0496 - val_classifier_output_accuracy: 0.9069
# Epoch 21/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.1384 - relu_decoder_loss: 0.0832 - classifier_output_loss: 0.3643 - relu_decoder_accuracy: 0.0513 - classifier_output_accuracy: 0.9089
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00021: val_loss improved from 0.13906 to 0.13845, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00021: val_loss improved from 0.13906 to 0.13845, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1384 - relu_decoder_loss: 0.0832 - classifier_output_loss: 0.3649 - relu_decoder_accuracy: 0.0513 - classifier_output_accuracy: 0.9087 - val_loss: 0.1385 - val_relu_decoder_loss: 0.0824 - val_classifier_output_loss: 0.3736 - val_relu_decoder_accuracy: 0.0479 - val_classifier_output_accuracy: 0.9065
# Epoch 22/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.1380 - relu_decoder_loss: 0.0832 - classifier_output_loss: 0.3624 - relu_decoder_accuracy: 0.0510 - classifier_output_accuracy: 0.9095
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00022: val_loss improved from 0.13845 to 0.13702, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00022: val_loss improved from 0.13845 to 0.13702, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1380 - relu_decoder_loss: 0.0832 - classifier_output_loss: 0.3621 - relu_decoder_accuracy: 0.0510 - classifier_output_accuracy: 0.9097 - val_loss: 0.1370 - val_relu_decoder_loss: 0.0828 - val_classifier_output_loss: 0.3567 - val_relu_decoder_accuracy: 0.0459 - val_classifier_output_accuracy: 0.9124
# Epoch 23/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1375 - relu_decoder_loss: 0.0832 - classifier_output_loss: 0.3581 - relu_decoder_accuracy: 0.0506 - classifier_output_accuracy: 0.9106
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00023: val_loss improved from 0.13702 to 0.13698, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 0.13702 to 0.13698, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1374 - relu_decoder_loss: 0.0832 - classifier_output_loss: 0.3576 - relu_decoder_accuracy: 0.0508 - classifier_output_accuracy: 0.9107 - val_loss: 0.1370 - val_relu_decoder_loss: 0.0835 - val_classifier_output_loss: 0.3507 - val_relu_decoder_accuracy: 0.0424 - val_classifier_output_accuracy: 0.9142
# Epoch 24/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.1369 - relu_decoder_loss: 0.0831 - classifier_output_loss: 0.3531 - relu_decoder_accuracy: 0.0528 - classifier_output_accuracy: 0.9120
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00024: val_loss did not improve from 0.13698
#
# Epoch 00024: val_loss did not improve from 0.13698
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1369 - relu_decoder_loss: 0.0831 - classifier_output_loss: 0.3538 - relu_decoder_accuracy: 0.0527 - classifier_output_accuracy: 0.9117 - val_loss: 0.1380 - val_relu_decoder_loss: 0.0831 - val_classifier_output_loss: 0.3657 - val_relu_decoder_accuracy: 0.0497 - val_classifier_output_accuracy: 0.9096
# Epoch 25/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1366 - relu_decoder_loss: 0.0828 - classifier_output_loss: 0.3545 - relu_decoder_accuracy: 0.0529 - classifier_output_accuracy: 0.9108
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00025: val_loss did not improve from 0.13698
#
# Epoch 00025: val_loss did not improve from 0.13698
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1366 - relu_decoder_loss: 0.0829 - classifier_output_loss: 0.3543 - relu_decoder_accuracy: 0.0529 - classifier_output_accuracy: 0.9105 - val_loss: 0.1386 - val_relu_decoder_loss: 0.0828 - val_classifier_output_loss: 0.3757 - val_relu_decoder_accuracy: 0.0438 - val_classifier_output_accuracy: 0.9070
# Epoch 26/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1359 - relu_decoder_loss: 0.0829 - classifier_output_loss: 0.3480 - relu_decoder_accuracy: 0.0525 - classifier_output_accuracy: 0.9133
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00026: val_loss did not improve from 0.13698
#
# Epoch 00026: val_loss did not improve from 0.13698
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1359 - relu_decoder_loss: 0.0829 - classifier_output_loss: 0.3476 - relu_decoder_accuracy: 0.0524 - classifier_output_accuracy: 0.9135 - val_loss: 0.1374 - val_relu_decoder_loss: 0.0826 - val_classifier_output_loss: 0.3669 - val_relu_decoder_accuracy: 0.0444 - val_classifier_output_accuracy: 0.9086
# Epoch 27/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.1353 - relu_decoder_loss: 0.0829 - classifier_output_loss: 0.3427 - relu_decoder_accuracy: 0.0536 - classifier_output_accuracy: 0.9145
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00027: val_loss improved from 0.13698 to 0.13646, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00027: val_loss improved from 0.13698 to 0.13646, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1353 - relu_decoder_loss: 0.0829 - classifier_output_loss: 0.3431 - relu_decoder_accuracy: 0.0537 - classifier_output_accuracy: 0.9144 - val_loss: 0.1365 - val_relu_decoder_loss: 0.0828 - val_classifier_output_loss: 0.3560 - val_relu_decoder_accuracy: 0.0531 - val_classifier_output_accuracy: 0.9118
# Epoch 28/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1349 - relu_decoder_loss: 0.0827 - classifier_output_loss: 0.3412 - relu_decoder_accuracy: 0.0541 - classifier_output_accuracy: 0.9154
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00028: val_loss improved from 0.13646 to 0.13509, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.13646 to 0.13509, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1348 - relu_decoder_loss: 0.0827 - classifier_output_loss: 0.3400 - relu_decoder_accuracy: 0.0539 - classifier_output_accuracy: 0.9156 - val_loss: 0.1351 - val_relu_decoder_loss: 0.0823 - val_classifier_output_loss: 0.3481 - val_relu_decoder_accuracy: 0.0464 - val_classifier_output_accuracy: 0.9149
# Epoch 29/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.1348 - relu_decoder_loss: 0.0828 - classifier_output_loss: 0.3405 - relu_decoder_accuracy: 0.0545 - classifier_output_accuracy: 0.9143
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00029: val_loss did not improve from 0.13509
#
# Epoch 00029: val_loss did not improve from 0.13509
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1348 - relu_decoder_loss: 0.0828 - classifier_output_loss: 0.3403 - relu_decoder_accuracy: 0.0547 - classifier_output_accuracy: 0.9144 - val_loss: 0.1355 - val_relu_decoder_loss: 0.0823 - val_classifier_output_loss: 0.3526 - val_relu_decoder_accuracy: 0.0510 - val_classifier_output_accuracy: 0.9118
# Epoch 30/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.1346 - relu_decoder_loss: 0.0827 - classifier_output_loss: 0.3401 - relu_decoder_accuracy: 0.0560 - classifier_output_accuracy: 0.9153
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00030: val_loss did not improve from 0.13509
#
# Epoch 00030: val_loss did not improve from 0.13509
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1346 - relu_decoder_loss: 0.0827 - classifier_output_loss: 0.3403 - relu_decoder_accuracy: 0.0558 - classifier_output_accuracy: 0.9151 - val_loss: 0.1358 - val_relu_decoder_loss: 0.0820 - val_classifier_output_loss: 0.3591 - val_relu_decoder_accuracy: 0.0438 - val_classifier_output_accuracy: 0.9140
# Epoch 31/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1339 - relu_decoder_loss: 0.0825 - classifier_output_loss: 0.3358 - relu_decoder_accuracy: 0.0553 - classifier_output_accuracy: 0.9161
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00031: val_loss did not improve from 0.13509
#
# Epoch 00031: val_loss did not improve from 0.13509
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1340 - relu_decoder_loss: 0.0825 - classifier_output_loss: 0.3362 - relu_decoder_accuracy: 0.0550 - classifier_output_accuracy: 0.9160 - val_loss: 0.1368 - val_relu_decoder_loss: 0.0825 - val_classifier_output_loss: 0.3646 - val_relu_decoder_accuracy: 0.0500 - val_classifier_output_accuracy: 0.9086
# Epoch 32/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.1334 - relu_decoder_loss: 0.0823 - classifier_output_loss: 0.3334 - relu_decoder_accuracy: 0.0544 - classifier_output_accuracy: 0.9183
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00032: val_loss improved from 0.13509 to 0.13484, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00032: val_loss improved from 0.13509 to 0.13484, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1334 - relu_decoder_loss: 0.0823 - classifier_output_loss: 0.3330 - relu_decoder_accuracy: 0.0547 - classifier_output_accuracy: 0.9185 - val_loss: 0.1348 - val_relu_decoder_loss: 0.0821 - val_classifier_output_loss: 0.3500 - val_relu_decoder_accuracy: 0.0484 - val_classifier_output_accuracy: 0.9154
# Epoch 33/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1332 - relu_decoder_loss: 0.0822 - classifier_output_loss: 0.3326 - relu_decoder_accuracy: 0.0556 - classifier_output_accuracy: 0.9168
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00033: val_loss improved from 0.13484 to 0.13473, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00033: val_loss improved from 0.13484 to 0.13473, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1332 - relu_decoder_loss: 0.0822 - classifier_output_loss: 0.3329 - relu_decoder_accuracy: 0.0553 - classifier_output_accuracy: 0.9168 - val_loss: 0.1347 - val_relu_decoder_loss: 0.0821 - val_classifier_output_loss: 0.3496 - val_relu_decoder_accuracy: 0.0547 - val_classifier_output_accuracy: 0.9159
# Epoch 34/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1330 - relu_decoder_loss: 0.0822 - classifier_output_loss: 0.3322 - relu_decoder_accuracy: 0.0561 - classifier_output_accuracy: 0.9174
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00034: val_loss improved from 0.13473 to 0.13461, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00034: val_loss improved from 0.13473 to 0.13461, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1330 - relu_decoder_loss: 0.0821 - classifier_output_loss: 0.3319 - relu_decoder_accuracy: 0.0562 - classifier_output_accuracy: 0.9172 - val_loss: 0.1346 - val_relu_decoder_loss: 0.0820 - val_classifier_output_loss: 0.3496 - val_relu_decoder_accuracy: 0.0440 - val_classifier_output_accuracy: 0.9147
# Epoch 35/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.1326 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.3311 - relu_decoder_accuracy: 0.0566 - classifier_output_accuracy: 0.9179
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00035: val_loss improved from 0.13461 to 0.13427, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00035: val_loss improved from 0.13461 to 0.13427, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1326 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.3311 - relu_decoder_accuracy: 0.0567 - classifier_output_accuracy: 0.9179 - val_loss: 0.1343 - val_relu_decoder_loss: 0.0811 - val_classifier_output_loss: 0.3563 - val_relu_decoder_accuracy: 0.0503 - val_classifier_output_accuracy: 0.9131
# Epoch 36/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.1325 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.3309 - relu_decoder_accuracy: 0.0574 - classifier_output_accuracy: 0.9179
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00036: val_loss improved from 0.13427 to 0.13292, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00036: val_loss improved from 0.13427 to 0.13292, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1325 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.3308 - relu_decoder_accuracy: 0.0578 - classifier_output_accuracy: 0.9178 - val_loss: 0.1329 - val_relu_decoder_loss: 0.0819 - val_classifier_output_loss: 0.3352 - val_relu_decoder_accuracy: 0.0502 - val_classifier_output_accuracy: 0.9193
# Epoch 37/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1318 - relu_decoder_loss: 0.0818 - classifier_output_loss: 0.3245 - relu_decoder_accuracy: 0.0572 - classifier_output_accuracy: 0.9196
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00037: val_loss did not improve from 0.13292
#
# Epoch 00037: val_loss did not improve from 0.13292
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1319 - relu_decoder_loss: 0.0818 - classifier_output_loss: 0.3264 - relu_decoder_accuracy: 0.0569 - classifier_output_accuracy: 0.9191 - val_loss: 0.1332 - val_relu_decoder_loss: 0.0817 - val_classifier_output_loss: 0.3405 - val_relu_decoder_accuracy: 0.0441 - val_classifier_output_accuracy: 0.9154
# Epoch 38/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1318 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.3255 - relu_decoder_accuracy: 0.0581 - classifier_output_accuracy: 0.9192
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00038: val_loss did not improve from 0.13292
#
# Epoch 00038: val_loss did not improve from 0.13292
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1317 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.3245 - relu_decoder_accuracy: 0.0581 - classifier_output_accuracy: 0.9196 - val_loss: 0.1331 - val_relu_decoder_loss: 0.0815 - val_classifier_output_loss: 0.3419 - val_relu_decoder_accuracy: 0.0537 - val_classifier_output_accuracy: 0.9149
# Epoch 39/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.1314 - relu_decoder_loss: 0.0818 - classifier_output_loss: 0.3225 - relu_decoder_accuracy: 0.0577 - classifier_output_accuracy: 0.9199
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00039: val_loss improved from 0.13292 to 0.13270, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00039: val_loss improved from 0.13292 to 0.13270, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1314 - relu_decoder_loss: 0.0818 - classifier_output_loss: 0.3225 - relu_decoder_accuracy: 0.0578 - classifier_output_accuracy: 0.9200 - val_loss: 0.1327 - val_relu_decoder_loss: 0.0822 - val_classifier_output_loss: 0.3312 - val_relu_decoder_accuracy: 0.0552 - val_classifier_output_accuracy: 0.9179
# Epoch 40/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.1312 - relu_decoder_loss: 0.0818 - classifier_output_loss: 0.3206 - relu_decoder_accuracy: 0.0592 - classifier_output_accuracy: 0.9209
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00040: val_loss improved from 0.13270 to 0.13195, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00040: val_loss improved from 0.13270 to 0.13195, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1313 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.3217 - relu_decoder_accuracy: 0.0590 - classifier_output_accuracy: 0.9206 - val_loss: 0.1319 - val_relu_decoder_loss: 0.0814 - val_classifier_output_loss: 0.3324 - val_relu_decoder_accuracy: 0.0544 - val_classifier_output_accuracy: 0.9208

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=True)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data(epochs=40,use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Compressed QAE with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="Compressed QAE with classifier")
# Out:
# WARNING:tensorflow:From C:\Users\loren\AppData\Roaming\Python\Python38\site-packages\tensorflow_model_optimization\python\core\sparsity\keras\pruning_wrapper.py:212: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 64)]         0
# __________________________________________________________________________________________________
# fc1 (QDense)                    (None, 32)           2080        encoder_input[0][0]
# __________________________________________________________________________________________________
# relu1 (QActivation)             (None, 32)           0           fc1[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_fc2_prun (P (None, 16)           1042        relu1[0][0]
# __________________________________________________________________________________________________
# relu2 (QActivation)             (None, 16)           0           prune_low_magnitude_fc2_prun[0][0
# __________________________________________________________________________________________________
# encoder_output (Dense)          (None, 2)            34          relu2[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_fc3 (PruneL (None, 16)           82          encoder_output[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_fc4_prunedc (None, 16)           82          encoder_output[0][0]
# __________________________________________________________________________________________________
# relu3 (QActivation)             (None, 16)           0           prune_low_magnitude_fc3[0][0]
# __________________________________________________________________________________________________
# prunclass_relu4 (QActivation)   (None, 16)           0           prune_low_magnitude_fc4_prunedcla
# __________________________________________________________________________________________________
# fc4 (QDense)                    (None, 32)           544         relu3[0][0]
# __________________________________________________________________________________________________
# fc5_class (QDense)              (None, 32)           544         prunclass_relu4[0][0]
# __________________________________________________________________________________________________
# relu4 (QActivation)             (None, 32)           0           fc4[0][0]
# __________________________________________________________________________________________________
# class_relu5 (QActivation)       (None, 32)           0           fc5_class[0][0]
# __________________________________________________________________________________________________
# decoder_output (QDense)         (None, 64)           2112        relu4[0][0]
# __________________________________________________________________________________________________
# classifier_out (QDense)         (None, 10)           330         class_relu5[0][0]
# __________________________________________________________________________________________________
# relu_decoder (QActivation)      (None, 64)           0           decoder_output[0][0]
# __________________________________________________________________________________________________
# classifier_output (Activation)  (None, 10)           0           classifier_out[0][0]
# ==================================================================================================
# Total params: 6,850
# Trainable params: 6,268
# Non-trainable params: 582
# __________________________________________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/40
#   1/235 [..............................] - ETA: 0s - loss: 0.4133 - relu_decoder_loss: 0.1657 - classifier_output_loss: 2.2975 - relu_decoder_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.0859WARNING:tensorflow:From C:\Users\loren\miniconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/235 [..............................] - ETA: 10s - loss: 0.4123 - relu_decoder_loss: 0.1646 - classifier_output_loss: 2.2983 - relu_decoder_accuracy: 0.0020 - classifier_output_accuracy: 0.1094   WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0702s). Check your callbacks.
# 226/235 [===========================>..] - ETA: 0s - loss: 0.3238 - relu_decoder_loss: 0.1077 - classifier_output_loss: 2.0216 - relu_decoder_accuracy: 0.0599 - classifier_output_accuracy: 0.2754
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00001: val_loss improved from inf to 0.27441, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 0.27441, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3221 - relu_decoder_loss: 0.1072 - classifier_output_loss: 2.0102 - relu_decoder_accuracy: 0.0603 - classifier_output_accuracy: 0.2825 - val_loss: 0.2744 - val_relu_decoder_loss: 0.0937 - val_classifier_output_loss: 1.6873 - val_relu_decoder_accuracy: 0.0817 - val_classifier_output_accuracy: 0.4762
# Epoch 2/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.2402 - relu_decoder_loss: 0.0882 - classifier_output_loss: 1.3931 - relu_decoder_accuracy: 0.0791 - classifier_output_accuracy: 0.5340
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00002: val_loss improved from 0.27441 to 0.21348, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 0.27441 to 0.21348, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2395 - relu_decoder_loss: 0.0881 - classifier_output_loss: 1.3863 - relu_decoder_accuracy: 0.0791 - classifier_output_accuracy: 0.5365 - val_loss: 0.2135 - val_relu_decoder_loss: 0.0858 - val_classifier_output_loss: 1.1384 - val_relu_decoder_accuracy: 0.0651 - val_classifier_output_accuracy: 0.6170
# Epoch 3/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.2020 - relu_decoder_loss: 0.0842 - classifier_output_loss: 1.0327 - relu_decoder_accuracy: 0.0665 - classifier_output_accuracy: 0.6457
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00003: val_loss improved from 0.21348 to 0.19180, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 0.21348 to 0.19180, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2018 - relu_decoder_loss: 0.0841 - classifier_output_loss: 1.0301 - relu_decoder_accuracy: 0.0666 - classifier_output_accuracy: 0.6462 - val_loss: 0.1918 - val_relu_decoder_loss: 0.0832 - val_classifier_output_loss: 0.9333 - val_relu_decoder_accuracy: 0.0405 - val_classifier_output_accuracy: 0.6630
# Epoch 4/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.1848 - relu_decoder_loss: 0.0826 - classifier_output_loss: 0.8636 - relu_decoder_accuracy: 0.0605 - classifier_output_accuracy: 0.6956
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00004: val_loss improved from 0.19180 to 0.17715, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.19180 to 0.17715, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1847 - relu_decoder_loss: 0.0826 - classifier_output_loss: 0.8632 - relu_decoder_accuracy: 0.0605 - classifier_output_accuracy: 0.6958 - val_loss: 0.1771 - val_relu_decoder_loss: 0.0821 - val_classifier_output_loss: 0.7877 - val_relu_decoder_accuracy: 0.0481 - val_classifier_output_accuracy: 0.7320
# Epoch 5/40
# 215/235 [==========================>...] - ETA: 0s - loss: 0.1750 - relu_decoder_loss: 0.0822 - classifier_output_loss: 0.7627 - relu_decoder_accuracy: 0.0612 - classifier_output_accuracy: 0.7336
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00005: val_loss improved from 0.17715 to 0.17023, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00005: val_loss improved from 0.17715 to 0.17023, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1748 - relu_decoder_loss: 0.0822 - classifier_output_loss: 0.7604 - relu_decoder_accuracy: 0.0606 - classifier_output_accuracy: 0.7346 - val_loss: 0.1702 - val_relu_decoder_loss: 0.0821 - val_classifier_output_loss: 0.7127 - val_relu_decoder_accuracy: 0.0619 - val_classifier_output_accuracy: 0.7443
# Epoch 6/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1690 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.7005 - relu_decoder_accuracy: 0.0615 - classifier_output_accuracy: 0.7554
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00006: val_loss improved from 0.17023 to 0.16603, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00006: val_loss improved from 0.17023 to 0.16603, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1688 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.6981 - relu_decoder_accuracy: 0.0615 - classifier_output_accuracy: 0.7567 - val_loss: 0.1660 - val_relu_decoder_loss: 0.0816 - val_classifier_output_loss: 0.6716 - val_relu_decoder_accuracy: 0.0518 - val_classifier_output_accuracy: 0.7739
# Epoch 7/40
# 212/235 [==========================>...] - ETA: 0s - loss: 0.1648 - relu_decoder_loss: 0.0816 - classifier_output_loss: 0.6583 - relu_decoder_accuracy: 0.0609 - classifier_output_accuracy: 0.7721
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00007: val_loss improved from 0.16603 to 0.16224, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00007: val_loss improved from 0.16603 to 0.16224, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1646 - relu_decoder_loss: 0.0816 - classifier_output_loss: 0.6573 - relu_decoder_accuracy: 0.0610 - classifier_output_accuracy: 0.7716 - val_loss: 0.1622 - val_relu_decoder_loss: 0.0812 - val_classifier_output_loss: 0.6368 - val_relu_decoder_accuracy: 0.0616 - val_classifier_output_accuracy: 0.7768
# Epoch 8/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.1609 - relu_decoder_loss: 0.0809 - classifier_output_loss: 0.6258 - relu_decoder_accuracy: 0.0641 - classifier_output_accuracy: 0.7906
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00008: val_loss improved from 0.16224 to 0.15963, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00008: val_loss improved from 0.16224 to 0.15963, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1609 - relu_decoder_loss: 0.0809 - classifier_output_loss: 0.6255 - relu_decoder_accuracy: 0.0643 - classifier_output_accuracy: 0.7912 - val_loss: 0.1596 - val_relu_decoder_loss: 0.0810 - val_classifier_output_loss: 0.6112 - val_relu_decoder_accuracy: 0.0855 - val_classifier_output_accuracy: 0.8228
# Epoch 9/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.2217 - relu_decoder_loss: 0.0916 - classifier_output_loss: 1.1277 - relu_decoder_accuracy: 0.0707 - classifier_output_accuracy: 0.6808
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00009: val_loss did not improve from 0.15963
#
# Epoch 00009: val_loss did not improve from 0.15963
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2220 - relu_decoder_loss: 0.0918 - classifier_output_loss: 1.1288 - relu_decoder_accuracy: 0.0722 - classifier_output_accuracy: 0.6815 - val_loss: 0.2256 - val_relu_decoder_loss: 0.0958 - val_classifier_output_loss: 1.1239 - val_relu_decoder_accuracy: 0.0876 - val_classifier_output_accuracy: 0.6896
# Epoch 10/40
# 217/235 [==========================>...] - ETA: 0s - loss: 0.2082 - relu_decoder_loss: 0.0930 - classifier_output_loss: 0.9712 - relu_decoder_accuracy: 0.0827 - classifier_output_accuracy: 0.7227
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00010: val_loss did not improve from 0.15963
#
# Epoch 00010: val_loss did not improve from 0.15963
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2073 - relu_decoder_loss: 0.0929 - classifier_output_loss: 0.9628 - relu_decoder_accuracy: 0.0827 - classifier_output_accuracy: 0.7273 - val_loss: 0.1946 - val_relu_decoder_loss: 0.0910 - val_classifier_output_loss: 0.8497 - val_relu_decoder_accuracy: 0.0791 - val_classifier_output_accuracy: 0.7978
# Epoch 11/40
# 216/235 [==========================>...] - ETA: 0s - loss: 0.1895 - relu_decoder_loss: 0.0894 - classifier_output_loss: 0.8127 - relu_decoder_accuracy: 0.0763 - classifier_output_accuracy: 0.7931
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00011: val_loss did not improve from 0.15963
#
# Epoch 00011: val_loss did not improve from 0.15963
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1891 - relu_decoder_loss: 0.0893 - classifier_output_loss: 0.8094 - relu_decoder_accuracy: 0.0758 - classifier_output_accuracy: 0.7934 - val_loss: 0.1829 - val_relu_decoder_loss: 0.0874 - val_classifier_output_loss: 0.7638 - val_relu_decoder_accuracy: 0.0623 - val_classifier_output_accuracy: 0.8172
# Epoch 12/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.1788 - relu_decoder_loss: 0.0863 - classifier_output_loss: 0.7323 - relu_decoder_accuracy: 0.0836 - classifier_output_accuracy: 0.8180
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00012: val_loss did not improve from 0.15963
#
# Epoch 00012: val_loss did not improve from 0.15963
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1788 - relu_decoder_loss: 0.0863 - classifier_output_loss: 0.7316 - relu_decoder_accuracy: 0.0834 - classifier_output_accuracy: 0.8182 - val_loss: 0.1781 - val_relu_decoder_loss: 0.0858 - val_classifier_output_loss: 0.7294 - val_relu_decoder_accuracy: 0.0604 - val_classifier_output_accuracy: 0.8144
# Epoch 13/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1729 - relu_decoder_loss: 0.0849 - classifier_output_loss: 0.6851 - relu_decoder_accuracy: 0.0794 - classifier_output_accuracy: 0.8327
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00013: val_loss did not improve from 0.15963
#
# Epoch 00013: val_loss did not improve from 0.15963
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1726 - relu_decoder_loss: 0.0847 - classifier_output_loss: 0.6840 - relu_decoder_accuracy: 0.0800 - classifier_output_accuracy: 0.8329 - val_loss: 0.1674 - val_relu_decoder_loss: 0.0821 - val_classifier_output_loss: 0.6577 - val_relu_decoder_accuracy: 0.0828 - val_classifier_output_accuracy: 0.8374
# Epoch 14/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1674 - relu_decoder_loss: 0.0822 - classifier_output_loss: 0.6566 - relu_decoder_accuracy: 0.0798 - classifier_output_accuracy: 0.8314
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00014: val_loss did not improve from 0.15963
#
# Epoch 00014: val_loss did not improve from 0.15963
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1675 - relu_decoder_loss: 0.0822 - classifier_output_loss: 0.6569 - relu_decoder_accuracy: 0.0797 - classifier_output_accuracy: 0.8314 - val_loss: 0.1774 - val_relu_decoder_loss: 0.0840 - val_classifier_output_loss: 0.7395 - val_relu_decoder_accuracy: 0.0553 - val_classifier_output_accuracy: 0.7581
# Epoch 15/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1646 - relu_decoder_loss: 0.0821 - classifier_output_loss: 0.6297 - relu_decoder_accuracy: 0.0765 - classifier_output_accuracy: 0.8421
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00015: val_loss did not improve from 0.15963
#
# Epoch 00015: val_loss did not improve from 0.15963
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1644 - relu_decoder_loss: 0.0821 - classifier_output_loss: 0.6279 - relu_decoder_accuracy: 0.0772 - classifier_output_accuracy: 0.8425 - val_loss: 0.1634 - val_relu_decoder_loss: 0.0818 - val_classifier_output_loss: 0.6211 - val_relu_decoder_accuracy: 0.0745 - val_classifier_output_accuracy: 0.8367
# Epoch 16/40
# 220/235 [===========================>..] - ETA: 0s - loss: 0.1613 - relu_decoder_loss: 0.0820 - classifier_output_loss: 0.5987 - relu_decoder_accuracy: 0.0759 - classifier_output_accuracy: 0.8503
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00016: val_loss did not improve from 0.15963
#
# Epoch 00016: val_loss did not improve from 0.15963
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1611 - relu_decoder_loss: 0.0820 - classifier_output_loss: 0.5974 - relu_decoder_accuracy: 0.0768 - classifier_output_accuracy: 0.8504 - val_loss: 0.1599 - val_relu_decoder_loss: 0.0815 - val_classifier_output_loss: 0.5904 - val_relu_decoder_accuracy: 0.0673 - val_classifier_output_accuracy: 0.8618
# Epoch 17/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.1591 - relu_decoder_loss: 0.0820 - classifier_output_loss: 0.5780 - relu_decoder_accuracy: 0.0745 - classifier_output_accuracy: 0.8567
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00017: val_loss did not improve from 0.15963
#
# Epoch 00017: val_loss did not improve from 0.15963
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1591 - relu_decoder_loss: 0.0820 - classifier_output_loss: 0.5781 - relu_decoder_accuracy: 0.0745 - classifier_output_accuracy: 0.8567 - val_loss: 0.1629 - val_relu_decoder_loss: 0.0834 - val_classifier_output_loss: 0.6020 - val_relu_decoder_accuracy: 0.0579 - val_classifier_output_accuracy: 0.8296
# Epoch 18/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.1580 - relu_decoder_loss: 0.0819 - classifier_output_loss: 0.5692 - relu_decoder_accuracy: 0.0764 - classifier_output_accuracy: 0.8551
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00018: val_loss improved from 0.15963 to 0.15554, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 0.15963 to 0.15554, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1579 - relu_decoder_loss: 0.0818 - classifier_output_loss: 0.5685 - relu_decoder_accuracy: 0.0764 - classifier_output_accuracy: 0.8555 - val_loss: 0.1555 - val_relu_decoder_loss: 0.0815 - val_classifier_output_loss: 0.5491 - val_relu_decoder_accuracy: 0.0756 - val_classifier_output_accuracy: 0.8659
# Epoch 19/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.1560 - relu_decoder_loss: 0.0815 - classifier_output_loss: 0.5542 - relu_decoder_accuracy: 0.0762 - classifier_output_accuracy: 0.8573
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00019: val_loss did not improve from 0.15554
#
# Epoch 00019: val_loss did not improve from 0.15554
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1561 - relu_decoder_loss: 0.0816 - classifier_output_loss: 0.5546 - relu_decoder_accuracy: 0.0758 - classifier_output_accuracy: 0.8573 - val_loss: 0.1574 - val_relu_decoder_loss: 0.0822 - val_classifier_output_loss: 0.5617 - val_relu_decoder_accuracy: 0.0540 - val_classifier_output_accuracy: 0.8524
# Epoch 20/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1545 - relu_decoder_loss: 0.0812 - classifier_output_loss: 0.5439 - relu_decoder_accuracy: 0.0779 - classifier_output_accuracy: 0.8623
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00020: val_loss improved from 0.15554 to 0.15348, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00020: val_loss improved from 0.15554 to 0.15348, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1544 - relu_decoder_loss: 0.0812 - classifier_output_loss: 0.5432 - relu_decoder_accuracy: 0.0779 - classifier_output_accuracy: 0.8624 - val_loss: 0.1535 - val_relu_decoder_loss: 0.0810 - val_classifier_output_loss: 0.5368 - val_relu_decoder_accuracy: 0.0704 - val_classifier_output_accuracy: 0.8721
# Epoch 21/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1527 - relu_decoder_loss: 0.0812 - classifier_output_loss: 0.5280 - relu_decoder_accuracy: 0.0762 - classifier_output_accuracy: 0.8654
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00021: val_loss improved from 0.15348 to 0.15218, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00021: val_loss improved from 0.15348 to 0.15218, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1529 - relu_decoder_loss: 0.0812 - classifier_output_loss: 0.5292 - relu_decoder_accuracy: 0.0760 - classifier_output_accuracy: 0.8653 - val_loss: 0.1522 - val_relu_decoder_loss: 0.0808 - val_classifier_output_loss: 0.5264 - val_relu_decoder_accuracy: 0.0704 - val_classifier_output_accuracy: 0.8602
# Epoch 22/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.1512 - relu_decoder_loss: 0.0810 - classifier_output_loss: 0.5147 - relu_decoder_accuracy: 0.0744 - classifier_output_accuracy: 0.8703
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00022: val_loss improved from 0.15218 to 0.15000, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00022: val_loss improved from 0.15218 to 0.15000, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1512 - relu_decoder_loss: 0.0810 - classifier_output_loss: 0.5148 - relu_decoder_accuracy: 0.0744 - classifier_output_accuracy: 0.8702 - val_loss: 0.1500 - val_relu_decoder_loss: 0.0804 - val_classifier_output_loss: 0.5094 - val_relu_decoder_accuracy: 0.0734 - val_classifier_output_accuracy: 0.8755
# Epoch 23/40
# 217/235 [==========================>...] - ETA: 0s - loss: 0.1501 - relu_decoder_loss: 0.0808 - classifier_output_loss: 0.5070 - relu_decoder_accuracy: 0.0756 - classifier_output_accuracy: 0.8722
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00023: val_loss improved from 0.15000 to 0.14816, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 0.15000 to 0.14816, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1501 - relu_decoder_loss: 0.0808 - classifier_output_loss: 0.5071 - relu_decoder_accuracy: 0.0758 - classifier_output_accuracy: 0.8720 - val_loss: 0.1482 - val_relu_decoder_loss: 0.0801 - val_classifier_output_loss: 0.4949 - val_relu_decoder_accuracy: 0.0848 - val_classifier_output_accuracy: 0.8753
# Epoch 24/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.1492 - relu_decoder_loss: 0.0807 - classifier_output_loss: 0.4994 - relu_decoder_accuracy: 0.0738 - classifier_output_accuracy: 0.8750
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00024: val_loss did not improve from 0.14816
#
# Epoch 00024: val_loss did not improve from 0.14816
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1492 - relu_decoder_loss: 0.0807 - classifier_output_loss: 0.4995 - relu_decoder_accuracy: 0.0743 - classifier_output_accuracy: 0.8749 - val_loss: 0.1518 - val_relu_decoder_loss: 0.0805 - val_classifier_output_loss: 0.5284 - val_relu_decoder_accuracy: 0.0768 - val_classifier_output_accuracy: 0.8712
# Epoch 25/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.1486 - relu_decoder_loss: 0.0809 - classifier_output_loss: 0.4916 - relu_decoder_accuracy: 0.0733 - classifier_output_accuracy: 0.8766
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00025: val_loss improved from 0.14816 to 0.14808, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00025: val_loss improved from 0.14816 to 0.14808, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1486 - relu_decoder_loss: 0.0809 - classifier_output_loss: 0.4923 - relu_decoder_accuracy: 0.0733 - classifier_output_accuracy: 0.8764 - val_loss: 0.1481 - val_relu_decoder_loss: 0.0815 - val_classifier_output_loss: 0.4809 - val_relu_decoder_accuracy: 0.0654 - val_classifier_output_accuracy: 0.8828
# Epoch 26/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.1475 - relu_decoder_loss: 0.0808 - classifier_output_loss: 0.4824 - relu_decoder_accuracy: 0.0734 - classifier_output_accuracy: 0.8786
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00026: val_loss improved from 0.14808 to 0.14613, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00026: val_loss improved from 0.14808 to 0.14613, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1475 - relu_decoder_loss: 0.0808 - classifier_output_loss: 0.4825 - relu_decoder_accuracy: 0.0734 - classifier_output_accuracy: 0.8785 - val_loss: 0.1461 - val_relu_decoder_loss: 0.0804 - val_classifier_output_loss: 0.4731 - val_relu_decoder_accuracy: 0.0917 - val_classifier_output_accuracy: 0.8841
# Epoch 27/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1472 - relu_decoder_loss: 0.0806 - classifier_output_loss: 0.4814 - relu_decoder_accuracy: 0.0748 - classifier_output_accuracy: 0.8782
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00027: val_loss did not improve from 0.14613
#
# Epoch 00027: val_loss did not improve from 0.14613
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1469 - relu_decoder_loss: 0.0806 - classifier_output_loss: 0.4793 - relu_decoder_accuracy: 0.0745 - classifier_output_accuracy: 0.8788 - val_loss: 0.1467 - val_relu_decoder_loss: 0.0802 - val_classifier_output_loss: 0.4809 - val_relu_decoder_accuracy: 0.0808 - val_classifier_output_accuracy: 0.8833
# Epoch 28/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1461 - relu_decoder_loss: 0.0804 - classifier_output_loss: 0.4722 - relu_decoder_accuracy: 0.0761 - classifier_output_accuracy: 0.8810
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00028: val_loss improved from 0.14613 to 0.14558, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.14613 to 0.14558, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1461 - relu_decoder_loss: 0.0804 - classifier_output_loss: 0.4724 - relu_decoder_accuracy: 0.0763 - classifier_output_accuracy: 0.8810 - val_loss: 0.1456 - val_relu_decoder_loss: 0.0804 - val_classifier_output_loss: 0.4679 - val_relu_decoder_accuracy: 0.0645 - val_classifier_output_accuracy: 0.8833
# Epoch 29/40
# 219/235 [==========================>...] - ETA: 0s - loss: 0.1447 - relu_decoder_loss: 0.0804 - classifier_output_loss: 0.4596 - relu_decoder_accuracy: 0.0728 - classifier_output_accuracy: 0.8835
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00029: val_loss improved from 0.14558 to 0.14442, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00029: val_loss improved from 0.14558 to 0.14442, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1449 - relu_decoder_loss: 0.0804 - classifier_output_loss: 0.4620 - relu_decoder_accuracy: 0.0734 - classifier_output_accuracy: 0.8829 - val_loss: 0.1444 - val_relu_decoder_loss: 0.0798 - val_classifier_output_loss: 0.4632 - val_relu_decoder_accuracy: 0.0580 - val_classifier_output_accuracy: 0.8866
# Epoch 30/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.1439 - relu_decoder_loss: 0.0802 - classifier_output_loss: 0.4542 - relu_decoder_accuracy: 0.0763 - classifier_output_accuracy: 0.8856
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00030: val_loss did not improve from 0.14442
#
# Epoch 00030: val_loss did not improve from 0.14442
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1438 - relu_decoder_loss: 0.0802 - classifier_output_loss: 0.4535 - relu_decoder_accuracy: 0.0764 - classifier_output_accuracy: 0.8859 - val_loss: 0.1456 - val_relu_decoder_loss: 0.0796 - val_classifier_output_loss: 0.4772 - val_relu_decoder_accuracy: 0.0743 - val_classifier_output_accuracy: 0.8772
# Epoch 31/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.1438 - relu_decoder_loss: 0.0802 - classifier_output_loss: 0.4525 - relu_decoder_accuracy: 0.0728 - classifier_output_accuracy: 0.8864
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00031: val_loss improved from 0.14442 to 0.14288, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00031: val_loss improved from 0.14442 to 0.14288, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00031: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1437 - relu_decoder_loss: 0.0802 - classifier_output_loss: 0.4526 - relu_decoder_accuracy: 0.0724 - classifier_output_accuracy: 0.8863 - val_loss: 0.1429 - val_relu_decoder_loss: 0.0801 - val_classifier_output_loss: 0.4456 - val_relu_decoder_accuracy: 0.0695 - val_classifier_output_accuracy: 0.8879
# Epoch 32/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1429 - relu_decoder_loss: 0.0801 - classifier_output_loss: 0.4461 - relu_decoder_accuracy: 0.0737 - classifier_output_accuracy: 0.8861
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00032: val_loss improved from 0.14288 to 0.14231, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00032: val_loss improved from 0.14288 to 0.14231, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00032: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1431 - relu_decoder_loss: 0.0801 - classifier_output_loss: 0.4470 - relu_decoder_accuracy: 0.0734 - classifier_output_accuracy: 0.8857 - val_loss: 0.1423 - val_relu_decoder_loss: 0.0798 - val_classifier_output_loss: 0.4431 - val_relu_decoder_accuracy: 0.0831 - val_classifier_output_accuracy: 0.8892
# Epoch 33/40
# 218/235 [==========================>...] - ETA: 0s - loss: 0.1428 - relu_decoder_loss: 0.0800 - classifier_output_loss: 0.4472 - relu_decoder_accuracy: 0.0713 - classifier_output_accuracy: 0.8865
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00033: val_loss did not improve from 0.14231
#
# Epoch 00033: val_loss did not improve from 0.14231
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00033: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1428 - relu_decoder_loss: 0.0800 - classifier_output_loss: 0.4468 - relu_decoder_accuracy: 0.0716 - classifier_output_accuracy: 0.8868 - val_loss: 0.1471 - val_relu_decoder_loss: 0.0800 - val_classifier_output_loss: 0.4894 - val_relu_decoder_accuracy: 0.0808 - val_classifier_output_accuracy: 0.8816
# Epoch 34/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.1423 - relu_decoder_loss: 0.0801 - classifier_output_loss: 0.4415 - relu_decoder_accuracy: 0.0733 - classifier_output_accuracy: 0.8864
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00034: val_loss did not improve from 0.14231
#
# Epoch 00034: val_loss did not improve from 0.14231
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00034: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1423 - relu_decoder_loss: 0.0801 - classifier_output_loss: 0.4415 - relu_decoder_accuracy: 0.0732 - classifier_output_accuracy: 0.8865 - val_loss: 0.1426 - val_relu_decoder_loss: 0.0794 - val_classifier_output_loss: 0.4513 - val_relu_decoder_accuracy: 0.0844 - val_classifier_output_accuracy: 0.8885
# Epoch 35/40
# 216/235 [==========================>...] - ETA: 0s - loss: 0.1420 - relu_decoder_loss: 0.0801 - classifier_output_loss: 0.4388 - relu_decoder_accuracy: 0.0748 - classifier_output_accuracy: 0.8881
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00035: val_loss improved from 0.14231 to 0.14119, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00035: val_loss improved from 0.14231 to 0.14119, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00035: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1422 - relu_decoder_loss: 0.0801 - classifier_output_loss: 0.4397 - relu_decoder_accuracy: 0.0755 - classifier_output_accuracy: 0.8878 - val_loss: 0.1412 - val_relu_decoder_loss: 0.0800 - val_classifier_output_loss: 0.4318 - val_relu_decoder_accuracy: 0.0921 - val_classifier_output_accuracy: 0.8888
# Epoch 36/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.1415 - relu_decoder_loss: 0.0801 - classifier_output_loss: 0.4341 - relu_decoder_accuracy: 0.0720 - classifier_output_accuracy: 0.8888
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00036: val_loss improved from 0.14119 to 0.14076, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00036: val_loss improved from 0.14119 to 0.14076, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00036: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1415 - relu_decoder_loss: 0.0801 - classifier_output_loss: 0.4338 - relu_decoder_accuracy: 0.0723 - classifier_output_accuracy: 0.8889 - val_loss: 0.1408 - val_relu_decoder_loss: 0.0798 - val_classifier_output_loss: 0.4293 - val_relu_decoder_accuracy: 0.0596 - val_classifier_output_accuracy: 0.8932
# Epoch 37/40
# 215/235 [==========================>...] - ETA: 0s - loss: 0.1412 - relu_decoder_loss: 0.0801 - classifier_output_loss: 0.4312 - relu_decoder_accuracy: 0.0769 - classifier_output_accuracy: 0.8899
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00037: val_loss did not improve from 0.14076
#
# Epoch 00037: val_loss did not improve from 0.14076
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00037: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1412 - relu_decoder_loss: 0.0800 - classifier_output_loss: 0.4317 - relu_decoder_accuracy: 0.0764 - classifier_output_accuracy: 0.8897 - val_loss: 0.1420 - val_relu_decoder_loss: 0.0797 - val_classifier_output_loss: 0.4435 - val_relu_decoder_accuracy: 0.0743 - val_classifier_output_accuracy: 0.8860
# Epoch 38/40
# 221/235 [===========================>..] - ETA: 0s - loss: 0.1403 - relu_decoder_loss: 0.0799 - classifier_output_loss: 0.4241 - relu_decoder_accuracy: 0.0756 - classifier_output_accuracy: 0.8907
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00038: val_loss improved from 0.14076 to 0.14070, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00038: val_loss improved from 0.14076 to 0.14070, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00038: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1402 - relu_decoder_loss: 0.0799 - classifier_output_loss: 0.4234 - relu_decoder_accuracy: 0.0756 - classifier_output_accuracy: 0.8909 - val_loss: 0.1407 - val_relu_decoder_loss: 0.0793 - val_classifier_output_loss: 0.4344 - val_relu_decoder_accuracy: 0.0731 - val_classifier_output_accuracy: 0.8872
# Epoch 39/40
# 219/235 [==========================>...] - ETA: 0s - loss: 0.1401 - relu_decoder_loss: 0.0798 - classifier_output_loss: 0.4230 - relu_decoder_accuracy: 0.0731 - classifier_output_accuracy: 0.8916
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00039: val_loss improved from 0.14070 to 0.14051, saving model to model/QAE_model/model_2\KERAS_check_best_model.h5
#
# Epoch 00039: val_loss improved from 0.14070 to 0.14051, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00039: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1403 - relu_decoder_loss: 0.0798 - classifier_output_loss: 0.4250 - relu_decoder_accuracy: 0.0732 - classifier_output_accuracy: 0.8909 - val_loss: 0.1405 - val_relu_decoder_loss: 0.0800 - val_classifier_output_loss: 0.4255 - val_relu_decoder_accuracy: 0.0765 - val_classifier_output_accuracy: 0.8913
# Epoch 40/40
# 220/235 [===========================>..] - ETA: 0s - loss: 0.1394 - relu_decoder_loss: 0.0798 - classifier_output_loss: 0.4169 - relu_decoder_accuracy: 0.0720 - classifier_output_accuracy: 0.8932
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 00040: val_loss did not improve from 0.14051
#
# Epoch 00040: val_loss did not improve from 0.14051
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00040: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1394 - relu_decoder_loss: 0.0798 - classifier_output_loss: 0.4165 - relu_decoder_accuracy: 0.0733 - classifier_output_accuracy: 0.8934 - val_loss: 0.1406 - val_relu_decoder_loss: 0.0798 - val_classifier_output_loss: 0.4292 - val_relu_decoder_accuracy: 0.0881 - val_classifier_output_accuracy: 0.8882
