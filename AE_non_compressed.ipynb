# %%
import tensorflow as tf
from tensorflow.python.keras import Input
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.engine.keras_tensor import KerasTensor
from tensorflow.python.keras.engine.functional import Functional
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense
from tensorflow.python.keras.regularizers import l2
import os

from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning, prune_low_magnitude

from callbacks import all_callbacks

# %% [markdown]
# ### Import the MNIST data class and call it.

# %% [markdown]
# Original dataset and modified dataset with half resolution is shown below.

# %%
import MNIST_dataset as mnist
size_final = 10

data_zoom = mnist.MNISTData(size_final=size_final, color_depth=5)
test = data_zoom.x_test

plt.imshow(test[0].reshape(size_final,size_final), cmap='gray_r')
print(data_zoom.x_train.shape)
# Out:
# (60000, 100)

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
class Autoencoder:
    """Autoencoder Class"""

    def __init__(self, data: mnist.MNISTData, num_classes=10):
        self.x_train = data.x_train
        self.x_test = data.x_test
        self.y_train = data.y_train
        self.y_test = data.y_test

        self.num_classes = num_classes
        self.input_shape = (self.x_train.shape[-1],)
        self.input = Input(shape=self.input_shape, name='encoder_input')
        self.latent_dim = 2

        self.encoder = None
        self.encoder_model = None
        self.decoder = None
        self.latent_classifier = None
        self.autoencoder = None

        self.history = None

        

    def build_encoder(self):
        """Build your encoder architecture and store the output in self.encoder. 
        The final encoding dimension is 2."""
        #pruning_params = {"pruning_schedule" : pruning_schedule.ConstantSparsity(0.75, begin_step=2000, frequency=100)}
        #self.encoder = prune_low_magnitude(Dense(32,  activation='relu'), **pruning_params)(self.input)

        self.encoder = Dense(32,  activation='relu')(self.input)
        self.encoder = Dense(16,  activation='relu')(self.encoder)   
        self.encoder = Dense(self.latent_dim,  activation='relu', name = 'encoder_output')(self.encoder)
             
        #building a model for the encoder in order to be able to predict and plot the latent dimension
        self.encoder_model = Model(self.input, self.encoder, name='encoder')

    def build_decoder(self):
        """Build the decoder architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the decoder!")
        self.decoder = Dense(16, activation='relu')(self.encoder)
        self.decoder = Dense(32,activation='relu')(self.decoder)
        self.decoder = Dense(self.input_shape[0],activation='sigmoid', name='ecoder_output')(self.decoder)

    def build_classifier(self):
        """ Building the classifier architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the classifier!")
        self.latent_classifier = Dense(16, activation='relu')(self.encoder)
        self.latent_classifier = Dense(32, activation='relu')(self.latent_classifier)
        self.latent_classifier = Dense(self.num_classes, activation='softmax',name='classifier_output')(self.latent_classifier)

    def build_autoencoder(self, use_latent_classifier=False):
        """ Build the whole autoencoder Model from self.encoder and self.decoder."""
        self.dir()
        
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the autoencoder!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")
        if use_latent_classifier:
            if self.latent_classifier is None:
                raise RuntimeError("If you want to use the option with the latent classifier, you have to build it "
                                   "beforehand!")
            self.autoencoder = Model(self.input, outputs=[self.decoder, self.latent_classifier])
            self.autoencoder.compile(loss=['mse', 'categorical_crossentropy'], loss_weights=[1, 0.1], optimizer='adam',
                                     metrics="accuracy")
            self.autoencoder.save('model/AE_model/KERAS_check_model_w_classifier.h5')

        else:
            self.autoencoder = Model(self.input, outputs=self.decoder, name = 'autoencoder')
            self.autoencoder.compile(loss='mse', optimizer='adam') 
            self.autoencoder.save('model/AE_model/KERAS_check_model_wo_classifier.h5')
        self.autoencoder.summary()

    def fit_data(self, batch_size=256, epochs=40, use_latent_classifier=False):
        """Write the fit function for the autoencoder. 
        Storing the fit history in self.history to be able to plot the fitting scores."""
        if use_latent_classifier:
            self.history = self.autoencoder.fit(self.x_train, [self.x_train, self.y_train],
                                                validation_data=(self.x_test, [self.x_test, self.y_test]),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )
        else:        
            """callbacks = callbacks.all_callbacks(stop_patience = 1000,
                              lr_factor = 0.5,
                              lr_patience = 10,
                              lr_epsilon = 0.000001,
                              lr_cooldown = 2,
                              lr_minimum = 0.0000001,
                              outputDir = 'model_2')
            callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())"""                  
            self.history = self.autoencoder.fit(self.x_train, self.x_train,
                                                validation_data=(self.x_test, self.x_test),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True#, callbacks=callbacks
                                                )
            #self.autoencoder = strip_pruning(self.autoencoder)
            #self.autoencoder.save('model/AE_model/KERAS_check_best_model.h5')

        self.history = self.history.history

    def dir(self):
        """Creation of the folders path to store the results."""
        dir = os.path.join("images")
        if not os.path.exists(dir):
            os.mkdir(dir)
        dir2 = os.path.join("./images/AE")
        if not os.path.exists(dir2):
            os.mkdir(dir2)
        dir3 = os.path.join("model")
        if not os.path.exists(dir3):
            os.mkdir(dir3)
        dir4 = os.path.join("./model/AE_model")
        if not os.path.exists(dir4):
            os.mkdir(dir4)
        
    
    def plot_score(self, model_name=None):
        """Plots the scores achieved during the fitting."""
        plt.plot(self.history['loss'])
        plt.plot(self.history['val_loss'])
        plt.ylabel('Model Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='best')
        plt.title('Accuracy of {model_name}'.format(model_name=model_name))
        
        plt.savefig('./images/AE/Accuracy of {model_name}.png'.format(model_name=model_name))
        
        plt.show()

    def plot_latent_dimension(self, model_name = None):
        """Plots the latent dimension of the autoencoder."""
        prediction = self.encoder_model.predict(self.x_test)
        fig = plt.figure(figsize=(10, 10))
        fig.patch.set_facecolor("white")
        plt.scatter(prediction[:, 0], prediction[:, 1], c=np.argmax(self.y_test, axis=1), cmap="Set3")
        plt.colorbar()
        plt.title('Latent space {model_name}'.format(model_name=model_name))


        plt.savefig('./images/AE/Latent dimension of {model_name}.png'.format(model_name=model_name))

        plt.show()

    def plot_reco(self, use_latent_classifier = False):
        """Plotting reconstructed images"""
        
        n = 6
        plt.figure(figsize=(10, 3))
        reco_imgs = self.autoencoder.predict(self.x_test)
        img_size = int(np.sqrt(self.input_shape[0]))

        
        if use_latent_classifier :
            raise RuntimeError("You are considering the autoencoder with classifier!")
        else:
        
            for i in range(n):
                # Display original MNIST
                ax = plt.subplot(2, n, i + 1)
                plt.imshow(self.x_test[i].reshape(img_size,img_size), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)

                # Display reconstructed MNIST            
                ax = plt.subplot(2, n, i + n + 1)
                plt.imshow(reco_imgs[i].reshape(img_size,img_size), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)
            plt.savefig('./images/AE/reconstructed images.png')
            plt.show()

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = Autoencoder(data_zoom)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=5)
network.plot_latent_dimension("Autoencoder without classifier")
network.plot_reco()
network.plot_score(use_latent_classifier=False,model_name="Autoencoder without classifier")
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 100)]             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                3232
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 34
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                48
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                544
# _________________________________________________________________
# ecoder_output (Dense)        (None, 100)               3300
# =================================================================
# Total params: 7,686
# Trainable params: 7,686
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 235/235 [==============================] - 0s 2ms/step - loss: 0.1269 - val_loss: 0.0980
# Epoch 2/5
# 235/235 [==============================] - 0s 1ms/step - loss: 0.0912 - val_loss: 0.0857
# Epoch 3/5
# 235/235 [==============================] - 0s 1ms/step - loss: 0.0833 - val_loss: 0.0808
# Epoch 4/5
# 235/235 [==============================] - 0s 1ms/step - loss: 0.0807 - val_loss: 0.0794
# Epoch 5/5
# 235/235 [==============================] - 0s 1ms/step - loss: 0.0796 - val_loss: 0.0785
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a998305ee934> in <module>
#       6 network.plot_latent_dimension("Autoencoder without classifier")
#       7 network.plot_reco()
# ----> 8 network.plot_score(use_latent_classifier=False,model_name="Autoencoder without classifier")
#
# TypeError: plot_score() got an unexpected keyword argument 'use_latent_classifier'

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = Autoencoder(data_zoom)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data( batch_size=256,epochs=30, use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Autoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="Autoencoder with classifier")
# Out:
# Model: "functional_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 100)]        0
# __________________________________________________________________________________________________
# dense_86 (Dense)                (None, 32)           3232        encoder_input[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_dense_87 (P (None, 16)           1042        dense_86[0][0]
# __________________________________________________________________________________________________
# encoder_output (Dense)          (None, 2)            34          prune_low_magnitude_dense_87[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_dense_88 (P (None, 16)           82          encoder_output[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_dense_90 (P (None, 16)           82          encoder_output[0][0]
# __________________________________________________________________________________________________
# dense_89 (Dense)                (None, 32)           544         prune_low_magnitude_dense_88[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_dense_91 (P (None, 32)           1058        prune_low_magnitude_dense_90[0][0
# __________________________________________________________________________________________________
# ecoder_output (Dense)           (None, 100)          3300        dense_89[0][0]
# __________________________________________________________________________________________________
# classifier_output (Dense)       (None, 10)           330         prune_low_magnitude_dense_91[0][0
# ==================================================================================================
# Total params: 9,704
# Trainable params: 8,608
# Non-trainable params: 1,096
# __________________________________________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/30
# WARNING:tensorflow:AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x000002151673B9D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x000002151673B9D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x0000021516D1DAF0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x0000021516D1DAF0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x00000215102D0AF0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x00000215102D0AF0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x00000215084AA5E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x00000215084AA5E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x0000021510C81A60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x0000021510C81A60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x0000021506681700> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x0000021506681700> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x0000021510C819D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x0000021510C819D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x000002150601F4C0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Pruning.conditional_mask_update.<locals>.maybe_update_masks at 0x000002150601F4C0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#   2/235 [..............................] - ETA: 3:14 - loss: 0.4360 - ecoder_output_loss: 0.2055 - classifier_output_loss: 2.3049 - ecoder_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.0938WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0121s vs `on_train_batch_end` time: 1.6573s). Check your callbacks.
# 222/235 [===========================>..] - ETA: 0s - loss: 0.2944 - ecoder_output_loss: 0.1186 - classifier_output_loss: 1.7587 - ecoder_output_accuracy: 0.0546 - classifier_output_accuracy: 0.3110
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00001: val_loss improved from inf to 0.21264, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 0.21264, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 3s 12ms/step - loss: 0.2900 - ecoder_output_loss: 0.1172 - classifier_output_loss: 1.7284 - ecoder_output_accuracy: 0.0534 - classifier_output_accuracy: 0.3203 - val_loss: 0.2126 - val_ecoder_output_loss: 0.0927 - val_classifier_output_loss: 1.1992 - val_ecoder_output_accuracy: 0.0313 - val_classifier_output_accuracy: 0.4909
# Epoch 2/30
# 231/235 [============================>.] - ETA: 0s - loss: 0.1972 - ecoder_output_loss: 0.0907 - classifier_output_loss: 1.0644 - ecoder_output_accuracy: 0.0337 - classifier_output_accuracy: 0.5646
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00002: val_loss improved from 0.21264 to 0.17875, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 0.21264 to 0.17875, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1969 - ecoder_output_loss: 0.0907 - classifier_output_loss: 1.0621 - ecoder_output_accuracy: 0.0339 - classifier_output_accuracy: 0.5657 - val_loss: 0.1788 - val_ecoder_output_loss: 0.0887 - val_classifier_output_loss: 0.9004 - val_ecoder_output_accuracy: 0.0377 - val_classifier_output_accuracy: 0.6726
# Epoch 3/30
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1692 - ecoder_output_loss: 0.0884 - classifier_output_loss: 0.8079 - ecoder_output_accuracy: 0.0344 - classifier_output_accuracy: 0.7141
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00003: val_loss improved from 0.17875 to 0.15639, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 0.17875 to 0.15639, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1688 - ecoder_output_loss: 0.0884 - classifier_output_loss: 0.8035 - ecoder_output_accuracy: 0.0342 - classifier_output_accuracy: 0.7166 - val_loss: 0.1564 - val_ecoder_output_loss: 0.0861 - val_classifier_output_loss: 0.7030 - val_ecoder_output_accuracy: 0.0344 - val_classifier_output_accuracy: 0.7779
# Epoch 4/30
# 217/235 [==========================>...] - ETA: 0s - loss: 0.1500 - ecoder_output_loss: 0.0859 - classifier_output_loss: 0.6411 - ecoder_output_accuracy: 0.0357 - classifier_output_accuracy: 0.8019
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00004: val_loss improved from 0.15639 to 0.13852, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.15639 to 0.13852, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1493 - ecoder_output_loss: 0.0858 - classifier_output_loss: 0.6351 - ecoder_output_accuracy: 0.0360 - classifier_output_accuracy: 0.8041 - val_loss: 0.1385 - val_ecoder_output_loss: 0.0834 - val_classifier_output_loss: 0.5514 - val_ecoder_output_accuracy: 0.0375 - val_classifier_output_accuracy: 0.8380
# Epoch 5/30
# 221/235 [===========================>..] - ETA: 0s - loss: 0.1348 - ecoder_output_loss: 0.0833 - classifier_output_loss: 0.5153 - ecoder_output_accuracy: 0.0391 - classifier_output_accuracy: 0.8479
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00005: val_loss improved from 0.13852 to 0.12879, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00005: val_loss improved from 0.13852 to 0.12879, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00005: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1345 - ecoder_output_loss: 0.0832 - classifier_output_loss: 0.5128 - ecoder_output_accuracy: 0.0389 - classifier_output_accuracy: 0.8487 - val_loss: 0.1288 - val_ecoder_output_loss: 0.0813 - val_classifier_output_loss: 0.4748 - val_ecoder_output_accuracy: 0.0402 - val_classifier_output_accuracy: 0.8629
# Epoch 6/30
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1269 - ecoder_output_loss: 0.0816 - classifier_output_loss: 0.4529 - ecoder_output_accuracy: 0.0358 - classifier_output_accuracy: 0.8681
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00006: val_loss improved from 0.12879 to 0.12425, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00006: val_loss improved from 0.12879 to 0.12425, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00006: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1268 - ecoder_output_loss: 0.0816 - classifier_output_loss: 0.4518 - ecoder_output_accuracy: 0.0355 - classifier_output_accuracy: 0.8684 - val_loss: 0.1243 - val_ecoder_output_loss: 0.0804 - val_classifier_output_loss: 0.4380 - val_ecoder_output_accuracy: 0.0322 - val_classifier_output_accuracy: 0.8752
# Epoch 7/30
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1223 - ecoder_output_loss: 0.0809 - classifier_output_loss: 0.4131 - ecoder_output_accuracy: 0.0302 - classifier_output_accuracy: 0.8820
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00007: val_loss improved from 0.12425 to 0.12027, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00007: val_loss improved from 0.12425 to 0.12027, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00007: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1222 - ecoder_output_loss: 0.0809 - classifier_output_loss: 0.4127 - ecoder_output_accuracy: 0.0301 - classifier_output_accuracy: 0.8820 - val_loss: 0.1203 - val_ecoder_output_loss: 0.0799 - val_classifier_output_loss: 0.4041 - val_ecoder_output_accuracy: 0.0312 - val_classifier_output_accuracy: 0.8853
# Epoch 8/30
# 216/235 [==========================>...] - ETA: 0s - loss: 0.1189 - ecoder_output_loss: 0.0804 - classifier_output_loss: 0.3843 - ecoder_output_accuracy: 0.0261 - classifier_output_accuracy: 0.8912
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00008: val_loss improved from 0.12027 to 0.11793, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00008: val_loss improved from 0.12027 to 0.11793, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00008: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1190 - ecoder_output_loss: 0.0804 - classifier_output_loss: 0.3857 - ecoder_output_accuracy: 0.0264 - classifier_output_accuracy: 0.8908 - val_loss: 0.1179 - val_ecoder_output_loss: 0.0796 - val_classifier_output_loss: 0.3831 - val_ecoder_output_accuracy: 0.0193 - val_classifier_output_accuracy: 0.8914
# Epoch 9/30
# 215/235 [==========================>...] - ETA: 0s - loss: 0.1471 - ecoder_output_loss: 0.0836 - classifier_output_loss: 0.6346 - ecoder_output_accuracy: 0.0211 - classifier_output_accuracy: 0.8094
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00009: val_loss did not improve from 0.11793
#
# Epoch 00009: val_loss did not improve from 0.11793
#
# Epoch 00009: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1462 - ecoder_output_loss: 0.0835 - classifier_output_loss: 0.6273 - ecoder_output_accuracy: 0.0213 - classifier_output_accuracy: 0.8128 - val_loss: 0.1350 - val_ecoder_output_loss: 0.0812 - val_classifier_output_loss: 0.5380 - val_ecoder_output_accuracy: 0.0231 - val_classifier_output_accuracy: 0.8563
# Epoch 10/30
# 221/235 [===========================>..] - ETA: 0s - loss: 0.1271 - ecoder_output_loss: 0.0811 - classifier_output_loss: 0.4599 - ecoder_output_accuracy: 0.0206 - classifier_output_accuracy: 0.8765
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00010: val_loss did not improve from 0.11793
#
# Epoch 00010: val_loss did not improve from 0.11793
#
# Epoch 00010: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1268 - ecoder_output_loss: 0.0811 - classifier_output_loss: 0.4574 - ecoder_output_accuracy: 0.0203 - classifier_output_accuracy: 0.8770 - val_loss: 0.1222 - val_ecoder_output_loss: 0.0799 - val_classifier_output_loss: 0.4229 - val_ecoder_output_accuracy: 0.0181 - val_classifier_output_accuracy: 0.8832
# Epoch 11/30
# 214/235 [==========================>...] - ETA: 0s - loss: 0.1205 - ecoder_output_loss: 0.0805 - classifier_output_loss: 0.4001 - ecoder_output_accuracy: 0.0206 - classifier_output_accuracy: 0.8912
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00011: val_loss did not improve from 0.11793
#
# Epoch 00011: val_loss did not improve from 0.11793
#
# Epoch 00011: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1203 - ecoder_output_loss: 0.0805 - classifier_output_loss: 0.3982 - ecoder_output_accuracy: 0.0210 - classifier_output_accuracy: 0.8918 - val_loss: 0.1184 - val_ecoder_output_loss: 0.0795 - val_classifier_output_loss: 0.3894 - val_ecoder_output_accuracy: 0.0203 - val_classifier_output_accuracy: 0.8942
# Epoch 12/30
# 217/235 [==========================>...] - ETA: 0s - loss: 0.1170 - ecoder_output_loss: 0.0801 - classifier_output_loss: 0.3694 - ecoder_output_accuracy: 0.0210 - classifier_output_accuracy: 0.8994
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00012: val_loss improved from 0.11793 to 0.11635, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00012: val_loss improved from 0.11793 to 0.11635, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00012: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1172 - ecoder_output_loss: 0.0801 - classifier_output_loss: 0.3710 - ecoder_output_accuracy: 0.0210 - classifier_output_accuracy: 0.8992 - val_loss: 0.1164 - val_ecoder_output_loss: 0.0792 - val_classifier_output_loss: 0.3717 - val_ecoder_output_accuracy: 0.0192 - val_classifier_output_accuracy: 0.8994
# Epoch 13/30
# 220/235 [===========================>..] - ETA: 0s - loss: 0.1149 - ecoder_output_loss: 0.0797 - classifier_output_loss: 0.3519 - ecoder_output_accuracy: 0.0212 - classifier_output_accuracy: 0.9036
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00013: val_loss improved from 0.11635 to 0.11461, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00013: val_loss improved from 0.11635 to 0.11461, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00013: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1150 - ecoder_output_loss: 0.0797 - classifier_output_loss: 0.3527 - ecoder_output_accuracy: 0.0213 - classifier_output_accuracy: 0.9035 - val_loss: 0.1146 - val_ecoder_output_loss: 0.0789 - val_classifier_output_loss: 0.3568 - val_ecoder_output_accuracy: 0.0200 - val_classifier_output_accuracy: 0.9039
# Epoch 14/30
# 219/235 [==========================>...] - ETA: 0s - loss: 0.1135 - ecoder_output_loss: 0.0796 - classifier_output_loss: 0.3394 - ecoder_output_accuracy: 0.0226 - classifier_output_accuracy: 0.9073
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00014: val_loss improved from 0.11461 to 0.11333, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00014: val_loss improved from 0.11461 to 0.11333, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00014: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1135 - ecoder_output_loss: 0.0796 - classifier_output_loss: 0.3390 - ecoder_output_accuracy: 0.0222 - classifier_output_accuracy: 0.9073 - val_loss: 0.1133 - val_ecoder_output_loss: 0.0788 - val_classifier_output_loss: 0.3457 - val_ecoder_output_accuracy: 0.0175 - val_classifier_output_accuracy: 0.9061
# Epoch 15/30
# 220/235 [===========================>..] - ETA: 0s - loss: 0.1119 - ecoder_output_loss: 0.0794 - classifier_output_loss: 0.3250 - ecoder_output_accuracy: 0.0218 - classifier_output_accuracy: 0.9116
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00015: val_loss improved from 0.11333 to 0.11230, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00015: val_loss improved from 0.11333 to 0.11230, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00015: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1121 - ecoder_output_loss: 0.0794 - classifier_output_loss: 0.3271 - ecoder_output_accuracy: 0.0218 - classifier_output_accuracy: 0.9110 - val_loss: 0.1123 - val_ecoder_output_loss: 0.0785 - val_classifier_output_loss: 0.3379 - val_ecoder_output_accuracy: 0.0218 - val_classifier_output_accuracy: 0.9091
# Epoch 16/30
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1110 - ecoder_output_loss: 0.0792 - classifier_output_loss: 0.3180 - ecoder_output_accuracy: 0.0222 - classifier_output_accuracy: 0.9136
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00016: val_loss improved from 0.11230 to 0.11187, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00016: val_loss improved from 0.11230 to 0.11187, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00016: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1110 - ecoder_output_loss: 0.0792 - classifier_output_loss: 0.3178 - ecoder_output_accuracy: 0.0221 - classifier_output_accuracy: 0.9135 - val_loss: 0.1119 - val_ecoder_output_loss: 0.0784 - val_classifier_output_loss: 0.3351 - val_ecoder_output_accuracy: 0.0227 - val_classifier_output_accuracy: 0.9105
# Epoch 17/30
# 217/235 [==========================>...] - ETA: 0s - loss: 0.1099 - ecoder_output_loss: 0.0790 - classifier_output_loss: 0.3089 - ecoder_output_accuracy: 0.0235 - classifier_output_accuracy: 0.9162
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00017: val_loss improved from 0.11187 to 0.11123, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00017: val_loss improved from 0.11187 to 0.11123, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00017: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1100 - ecoder_output_loss: 0.0791 - classifier_output_loss: 0.3089 - ecoder_output_accuracy: 0.0235 - classifier_output_accuracy: 0.9159 - val_loss: 0.1112 - val_ecoder_output_loss: 0.0785 - val_classifier_output_loss: 0.3273 - val_ecoder_output_accuracy: 0.0177 - val_classifier_output_accuracy: 0.9134
# Epoch 18/30
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1091 - ecoder_output_loss: 0.0790 - classifier_output_loss: 0.3013 - ecoder_output_accuracy: 0.0230 - classifier_output_accuracy: 0.9180
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00018: val_loss improved from 0.11123 to 0.11020, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 0.11123 to 0.11020, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1090 - ecoder_output_loss: 0.0790 - classifier_output_loss: 0.3004 - ecoder_output_accuracy: 0.0231 - classifier_output_accuracy: 0.9183 - val_loss: 0.1102 - val_ecoder_output_loss: 0.0782 - val_classifier_output_loss: 0.3203 - val_ecoder_output_accuracy: 0.0230 - val_classifier_output_accuracy: 0.9156
# Epoch 19/30
# 233/235 [============================>.] - ETA: 0s - loss: 0.1082 - ecoder_output_loss: 0.0789 - classifier_output_loss: 0.2936 - ecoder_output_accuracy: 0.0235 - classifier_output_accuracy: 0.9199
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00019: val_loss improved from 0.11020 to 0.10953, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00019: val_loss improved from 0.11020 to 0.10953, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00019: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1082 - ecoder_output_loss: 0.0789 - classifier_output_loss: 0.2933 - ecoder_output_accuracy: 0.0236 - classifier_output_accuracy: 0.9201 - val_loss: 0.1095 - val_ecoder_output_loss: 0.0780 - val_classifier_output_loss: 0.3154 - val_ecoder_output_accuracy: 0.0210 - val_classifier_output_accuracy: 0.9164
# Epoch 20/30
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1074 - ecoder_output_loss: 0.0787 - classifier_output_loss: 0.2870 - ecoder_output_accuracy: 0.0235 - classifier_output_accuracy: 0.9218
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00020: val_loss improved from 0.10953 to 0.10945, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00020: val_loss improved from 0.10953 to 0.10945, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00020: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1074 - ecoder_output_loss: 0.0787 - classifier_output_loss: 0.2870 - ecoder_output_accuracy: 0.0235 - classifier_output_accuracy: 0.9220 - val_loss: 0.1095 - val_ecoder_output_loss: 0.0780 - val_classifier_output_loss: 0.3148 - val_ecoder_output_accuracy: 0.0188 - val_classifier_output_accuracy: 0.9178
# Epoch 21/30
# 229/235 [============================>.] - ETA: 0s - loss: 0.1066 - ecoder_output_loss: 0.0787 - classifier_output_loss: 0.2795 - ecoder_output_accuracy: 0.0228 - classifier_output_accuracy: 0.9237
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00021: val_loss improved from 0.10945 to 0.10848, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00021: val_loss improved from 0.10945 to 0.10848, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00021: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1067 - ecoder_output_loss: 0.0786 - classifier_output_loss: 0.2807 - ecoder_output_accuracy: 0.0228 - classifier_output_accuracy: 0.9234 - val_loss: 0.1085 - val_ecoder_output_loss: 0.0779 - val_classifier_output_loss: 0.3062 - val_ecoder_output_accuracy: 0.0223 - val_classifier_output_accuracy: 0.9196
# Epoch 22/30
# 233/235 [============================>.] - ETA: 0s - loss: 0.1061 - ecoder_output_loss: 0.0785 - classifier_output_loss: 0.2759 - ecoder_output_accuracy: 0.0244 - classifier_output_accuracy: 0.9249
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00022: val_loss improved from 0.10848 to 0.10827, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00022: val_loss improved from 0.10848 to 0.10827, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00022: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1061 - ecoder_output_loss: 0.0785 - classifier_output_loss: 0.2761 - ecoder_output_accuracy: 0.0244 - classifier_output_accuracy: 0.9248 - val_loss: 0.1083 - val_ecoder_output_loss: 0.0777 - val_classifier_output_loss: 0.3058 - val_ecoder_output_accuracy: 0.0210 - val_classifier_output_accuracy: 0.9211
# Epoch 23/30
# 221/235 [===========================>..] - ETA: 0s - loss: 0.1055 - ecoder_output_loss: 0.0784 - classifier_output_loss: 0.2704 - ecoder_output_accuracy: 0.0242 - classifier_output_accuracy: 0.9270
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00023: val_loss improved from 0.10827 to 0.10759, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 0.10827 to 0.10759, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1054 - ecoder_output_loss: 0.0784 - classifier_output_loss: 0.2702 - ecoder_output_accuracy: 0.0242 - classifier_output_accuracy: 0.9271 - val_loss: 0.1076 - val_ecoder_output_loss: 0.0777 - val_classifier_output_loss: 0.2986 - val_ecoder_output_accuracy: 0.0208 - val_classifier_output_accuracy: 0.9232
# Epoch 24/30
# 221/235 [===========================>..] - ETA: 0s - loss: 0.1049 - ecoder_output_loss: 0.0783 - classifier_output_loss: 0.2658 - ecoder_output_accuracy: 0.0233 - classifier_output_accuracy: 0.9278
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00024: val_loss did not improve from 0.10759
#
# Epoch 00024: val_loss did not improve from 0.10759
#
# Epoch 00024: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1049 - ecoder_output_loss: 0.0783 - classifier_output_loss: 0.2662 - ecoder_output_accuracy: 0.0237 - classifier_output_accuracy: 0.9275 - val_loss: 0.1078 - val_ecoder_output_loss: 0.0776 - val_classifier_output_loss: 0.3013 - val_ecoder_output_accuracy: 0.0193 - val_classifier_output_accuracy: 0.9230
# Epoch 25/30
# 221/235 [===========================>..] - ETA: 0s - loss: 0.1044 - ecoder_output_loss: 0.0782 - classifier_output_loss: 0.2623 - ecoder_output_accuracy: 0.0233 - classifier_output_accuracy: 0.9290
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00025: val_loss improved from 0.10759 to 0.10704, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00025: val_loss improved from 0.10759 to 0.10704, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00025: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1044 - ecoder_output_loss: 0.0782 - classifier_output_loss: 0.2620 - ecoder_output_accuracy: 0.0234 - classifier_output_accuracy: 0.9288 - val_loss: 0.1070 - val_ecoder_output_loss: 0.0775 - val_classifier_output_loss: 0.2957 - val_ecoder_output_accuracy: 0.0244 - val_classifier_output_accuracy: 0.9227
# Epoch 26/30
# 218/235 [==========================>...] - ETA: 0s - loss: 0.1039 - ecoder_output_loss: 0.0781 - classifier_output_loss: 0.2585 - ecoder_output_accuracy: 0.0234 - classifier_output_accuracy: 0.9295
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00026: val_loss improved from 0.10704 to 0.10615, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00026: val_loss improved from 0.10704 to 0.10615, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00026: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1038 - ecoder_output_loss: 0.0780 - classifier_output_loss: 0.2581 - ecoder_output_accuracy: 0.0232 - classifier_output_accuracy: 0.9297 - val_loss: 0.1062 - val_ecoder_output_loss: 0.0773 - val_classifier_output_loss: 0.2888 - val_ecoder_output_accuracy: 0.0205 - val_classifier_output_accuracy: 0.9267
# Epoch 27/30
# 223/235 [===========================>..] - ETA: 0s - loss: 0.1034 - ecoder_output_loss: 0.0779 - classifier_output_loss: 0.2549 - ecoder_output_accuracy: 0.0236 - classifier_output_accuracy: 0.9310
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00027: val_loss improved from 0.10615 to 0.10615, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00027: val_loss improved from 0.10615 to 0.10615, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00027: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1033 - ecoder_output_loss: 0.0779 - classifier_output_loss: 0.2543 - ecoder_output_accuracy: 0.0236 - classifier_output_accuracy: 0.9310 - val_loss: 0.1061 - val_ecoder_output_loss: 0.0770 - val_classifier_output_loss: 0.2914 - val_ecoder_output_accuracy: 0.0212 - val_classifier_output_accuracy: 0.9245
# Epoch 28/30
# 222/235 [===========================>..] - ETA: 0s - loss: 0.1028 - ecoder_output_loss: 0.0777 - classifier_output_loss: 0.2509 - ecoder_output_accuracy: 0.0232 - classifier_output_accuracy: 0.9322
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00028: val_loss improved from 0.10615 to 0.10598, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.10615 to 0.10598, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1028 - ecoder_output_loss: 0.0777 - classifier_output_loss: 0.2512 - ecoder_output_accuracy: 0.0232 - classifier_output_accuracy: 0.9320 - val_loss: 0.1060 - val_ecoder_output_loss: 0.0770 - val_classifier_output_loss: 0.2899 - val_ecoder_output_accuracy: 0.0177 - val_classifier_output_accuracy: 0.9254
# Epoch 29/30
# 234/235 [============================>.] - ETA: 0s - loss: 0.1023 - ecoder_output_loss: 0.0775 - classifier_output_loss: 0.2481 - ecoder_output_accuracy: 0.0219 - classifier_output_accuracy: 0.9327
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00029: val_loss improved from 0.10598 to 0.10560, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00029: val_loss improved from 0.10598 to 0.10560, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00029: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - ecoder_output_loss: 0.0775 - classifier_output_loss: 0.2482 - ecoder_output_accuracy: 0.0219 - classifier_output_accuracy: 0.9327 - val_loss: 0.1056 - val_ecoder_output_loss: 0.0768 - val_classifier_output_loss: 0.2880 - val_ecoder_output_accuracy: 0.0194 - val_classifier_output_accuracy: 0.9278
# Epoch 30/30
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1018 - ecoder_output_loss: 0.0773 - classifier_output_loss: 0.2448 - ecoder_output_accuracy: 0.0220 - classifier_output_accuracy: 0.9334
# ***callbacks***
# saving losses to model_2\losses.log
#
# Epoch 00030: val_loss improved from 0.10560 to 0.10530, saving model to model_2\KERAS_check_best_model.h5
#
# Epoch 00030: val_loss improved from 0.10560 to 0.10530, saving model to model_2\KERAS_check_best_model_weights.h5
#
# Epoch 00030: saving model to model_2\KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model_2\KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1018 - ecoder_output_loss: 0.0773 - classifier_output_loss: 0.2452 - ecoder_output_accuracy: 0.0219 - classifier_output_accuracy: 0.9332 - val_loss: 0.1053 - val_ecoder_output_loss: 0.0766 - val_classifier_output_loss: 0.2875 - val_ecoder_output_accuracy: 0.0231 - val_classifier_output_accuracy: 0.9270

# %%
w = network_with_classifier.encoder.layer[0].output.numpy()
h, b = np.histogram(w, bins=100)
plt.figure(figsize=(7,7))
plt.bar(b[:-1], h, width=b[1]-b[0])
plt.semilogy()
print('% of zeros = {}'.format(np.sum(w==0)/np.size(w)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-8a1dd0841107> in <module>
# ----> 1 w = network_with_classifier.layer.weights.numpy()
#       2 h, b = np.histogram(w, bins=100)
#       3 plt.figure(figsize=(7,7))
#       4 plt.bar(b[:-1], h, width=b[1]-b[0])
#       5 plt.semilogy()
#
# AttributeError: 'Autoencoder' object has no attribute 'layer'
